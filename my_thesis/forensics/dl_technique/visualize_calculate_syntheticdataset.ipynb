# %%
from model.cnn.xception_net.model import xception
import torch
from module.train_torch import calculate_metric
from dataloader.gen_dataloader import *
import random
import numpy as np
import os
import torch.nn as nn
from glob import glob
from tqdm import tqdm
from os.path import join
from utils.util import get_test_metric_by_step

torch.manual_seed(0)
random.seed(0)
np.random.seed(0)

def eval_kfold_image_stream(model ,dataloader, device, criterion, adj_brightness=1.0, adj_contrast=1.0 ):
    loss = 0
    mac_accuracy = 0
    model.eval()
    y_label = []
    y_pred_label = []
    with torch.no_grad():
        for inputs, labels in dataloader:
            # Push to device
            y_label.extend(labels.cpu().numpy().astype(np.float64))
            inputs, labels = inputs.float().to(device), labels.float().to(device)

            # Forward network
            logps = model.forward(inputs)
            if len(logps.shape) == 2:
                logps = logps.squeeze(dim=1)

            # Loss in a batch
            batch_loss = criterion(logps, labels)
            # Cumulate into running val loss
            loss += batch_loss.item()

            # Find accuracy
            equals = (labels == (logps > 0.5))
            mac_accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
            #
            logps_cpu = logps.cpu().numpy()
            pred_label = (logps_cpu > 0.5)
            y_pred_label.extend(pred_label)
            
    assert len(y_label) == len(y_pred_label), "Bug"
    ######## Calculate metrics:
    loss /= len(dataloader)
    mac_accuracy /= len(dataloader)
    # built-in methods for calculating metrics
    mic_accuracy, reals, fakes, micros, macros = calculate_metric(y_label, y_pred_label)
    return loss, mac_accuracy, mic_accuracy, reals, fakes, micros, macros

################### FROM DEEPFAKE TO OTHER DATASET:
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
device = torch.device('cuda')

test_dir_template = "/mnt/disk1/doan/phucnp/Dataset/my_extend_data/extend_data_train/{}/test"

checkpoints = {
    "deepfake": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/deepfake/kfold_xception/lr0.0002_batch16_esnone_lossbce_nf5_trick1_pre1_seed0_drmlp0.0_aug0",
    "faceswap_2d": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/faceswap_2d/kfold_xception/lr0.0002_batch16_esnone_lossbce_nf5_trick1_pre1_seed0_drmlp0.0_aug0",
    "3dmm": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/3dmm/kfold_xception/lr0.0002_batch16_esnone_lossbce_nf5_trick1_pre1_seed0_drmlp0.0_aug0",
    "faceswap_3d": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/faceswap_3d/kfold_xception/lr0.0002_batch16_esnone_lossbce_nf5_trick1_pre1_seed0_drmlp0.0_aug0",
    "monkey": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/monkey/kfold_xception/lr0.0002_batch16_esnone_lossbce_nf5_trick1_pre1_seed0_drmlp0.0_aug0",
    "reenact": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/reenact/kfold_xception/lr0.0002_batch16_esnone_lossbce_nf5_trick1_pre1_seed0_drmlp0.0_aug0",
    "stargan": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/stargan/kfold_xception/lr0.0002_batch16_esnone_lossbce_nf5_trick1_pre1_seed0_drmlp0.0_aug0",
    "x2face": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/x2face/kfold_xception/lr0.0002_batch16_esnone_lossbce_nf5_trick1_pre1_seed0_drmlp0.0_aug0"
}

for technique in ['deepfake', '3dmm', 'faceswap_2d', 'faceswap_3d', 'monkey', 'reenact', 'stargan', 'x2face']:
    checkpoint = checkpoints[technique]
    print("\n\n ==================================== {} CHECKPOINT =========================".format(technique))
    for idx, other_technique in enumerate(['deepfake', '3dmm', 'faceswap_2d', 'faceswap_3d', 'monkey', 'reenact', 'stargan', 'x2face']):
        print("\n************************ So sánh với technique: ", other_technique)
        my_break = False
        for pt_file in glob(join(checkpoint, '*/*/*.pt')):
            if 'best_val_loss' not in pt_file:
                continue
                
            fold_id = pt_file.split('/')[-3][-1]

            model_ = xception(pretrained=False)
            model_.load_state_dict(torch.load(pt_file))
            model_ = model_.to(device)
            
            batch_size = 16

            test_dir = test_dir_template.format(other_technique)
            dataloader_test = generate_test_dataloader_single_cnn_stream_for_kfold(test_dir, 128, batch_size, 4)

            criterion = nn.BCELoss().to(device)
            ####
            loss, mac_acc, mic_acc, reals, fakes, micros, macros = eval_kfold_image_stream(model_, dataloader_test, device, criterion)
            print("            pt file: ", '/'.join(pt_file.split('/')[-3:]))
            print("        {}. FOLD: {}    -   cross with dataset: {}".format(fold_id, idx, other_technique))
            print("            accuracy =   {:.6f}       |  {:6f}".format(mic_acc, mac_acc))
            print("            precision =  {:.6f}  |   recall =    {:.6f}   |  f1 =    {:.6f}".format(macros[0], macros[1], macros[2]))

            if other_technique == technique:
                step_ckcpoint = osp.split(pt_file)[0]
                step = int(osp.basename(pt_file).split('_')[-2])
                pairwise = True if 'pairwise' in pt_file else False
                metrics, bestloss = get_test_metric_by_step(step_ckcpoint=step_ckcpoint, steps=step, pairwise=pairwise)
                acc, pre, rec, f1 = metrics['best_val_bceloss']['acc'], metrics['best_val_bceloss']['pre'], metrics['best_val_bceloss']['rec'], metrics['best_val_bceloss']['f1']

                # if abs(round(loss, 4) - round(bestloss, 4)) > 0.001:
                #     print("         Error in loss: {}, {}".format(loss, bestloss))
                #     my_break = True
                if abs(round(mic_acc, 4) - round(acc, 4)) > 0.001:
                    print("         Error in acc: {}, {}".format(mic_acc, acc))
                    my_break = True
                if abs(round(macros[0], 4) - round(pre, 4)) > 0.001:
                    print("         Error in pre: {}, {}".format(macros[0], pre))
                    my_break = True
                if abs(round(macros[1], 4) - round(rec, 4)) > 0.001:
                    print("         Error in rec: {}, {}".format(macros[1], rec))
                    my_break = True
                if abs(round(macros[2], 4) - round(f1, 4)) > 0.001:
                    print("         Error in f1: {}, {}".format(macros[2], f1))
                    my_break = True

                if my_break:
                    break

        if my_break:
            break

    if my_break:
        break

# %%
from model.cnn.xception_net.model import xception
import torch
from module.train_torch import calculate_metric
from dataloader.gen_dataloader import *
import random
import numpy as np
import os
import torch.nn as nn
from glob import glob
from tqdm import tqdm
from os.path import join
from utils.util import get_test_metric_by_step
from model.cnn.capsule_net.model import VggExtractor, CapsuleNet
from loss.capsule_loss import CapsuleLoss
from torch.autograd import Variable
from sklearn.metrics import accuracy_score

torch.manual_seed(0)
random.seed(0)
np.random.seed(0)

def eval_kfold_capsulenet(capnet, vgg_ext, dataloader, device, capsule_loss):
    capnet.eval()
    vgg_ext.eval()

    y_label = []
    y_pred = []
    y_pred_label = []
    loss = 0
    mac_accuracy = 0
    
    for inputs, labels in dataloader:
        labels[labels > 1] = 1
        img_label = labels.numpy().astype(np.float)
        inputs, labels = inputs.to(device), labels.to(device)

        input_v = Variable(inputs)
        x = vgg_ext(input_v)
        classes, class_ = capnet(x, random=False)

        loss_dis = capsule_loss(classes, Variable(labels, requires_grad=False))
        loss_dis_data = loss_dis.item()
        output_dis = class_.data.cpu().numpy()

        output_pred = np.zeros((output_dis.shape[0]), dtype=np.float)

        for i in range(output_dis.shape[0]):
            if output_dis[i,1] >= output_dis[i,0]:
                output_pred[i] = 1.0
            else:
                output_pred[i] = 0.0

        loss += loss_dis_data
        y_label.extend(img_label)
        y_pred.extend(output_dis)
        y_pred_label.extend(output_pred)
        mac_accuracy += accuracy_score(img_label, output_pred)
        
    mac_accuracy /= len(dataloader)
    loss /= len(dataloader)
    assert len(y_label) == len(y_pred_label), "Bug"
    ######## Calculate metrics:
    # built-in methods for calculating metrics
    mic_accuracy, reals, fakes, micros, macros = calculate_metric(y_label, y_pred_label)
    return loss, mac_accuracy, mic_accuracy, reals, fakes, micros, macros


################### FROM DEEPFAKE TO OTHER DATASET:
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
device = torch.device('cuda')

test_dir_template = "/mnt/disk1/doan/phucnp/Dataset/my_extend_data/extend_data_train/{}/test"

checkpoints = {
    "deepfake": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/deepfake/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "faceswap_2d": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/faceswap_2d/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "3dmm": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/3dmm/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "faceswap_3d":"/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/faceswap_3d/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "monkey": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/monkey/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "reenact": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/reenact/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "stargan": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/stargan/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "x2face": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/x2face/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0"
}

for technique in ['deepfake', '3dmm', 'faceswap_2d', 'faceswap_3d', 'monkey', 'reenact', 'stargan', 'x2face']:
    checkpoint = checkpoints[technique]
    print("\n\n ==================================== {} CHECKPOINT =========================".format(technique))
    for idx, other_technique in enumerate(['deepfake', '3dmm', 'faceswap_2d', 'faceswap_3d', 'monkey', 'reenact', 'stargan', 'x2face']):
        print("\n************************ So sánh với technique: ", other_technique)
        my_break = False
        for fold_dir in glob(join(checkpoint, '*')):
                
            fold_id = fold_dir[-1]

            vgg_ext = VggExtractor().to(device)
            capnet = CapsuleNet(num_class=2, device=device).to(device)
            capsule_ckcpoint = glob(join(fold_dir, 'step', 'bestcapsule_val_loss*.pt'))[0]
            vggext_ckcpoint = glob(join(fold_dir, 'step', 'bestvgg_val_loss*.pt'))[0]
            vgg_ext.load_state_dict(torch.load(vggext_ckcpoint))
            capnet.load_state_dict(torch.load(capsule_ckcpoint))
            
            batch_size = 16

            test_dir = test_dir_template.format(other_technique)
            dataloader_test = generate_test_dataloader_single_cnn_stream_for_kfold(test_dir, 128, batch_size, 4)

            capsule_loss = CapsuleLoss().to(device)
            ####
            loss, mac_acc, mic_acc, reals, fakes, micros, macros = eval_kfold_capsulenet(capnet, vgg_ext, dataloader_test, device, capsule_loss)
            print("            pt file: ", '/'.join(capsule_ckcpoint.split('/')[-3:]))
            print("        {}. FOLD: {}    -   cross with dataset: {}".format(fold_id, idx, other_technique))
            print("            accuracy =   {:.6f}       |  {:6f}".format(mic_acc, mac_acc))
            print("            precision =  {:.6f}  |   recall =    {:.6f}   |  f1 =    {:.6f}".format(macros[0], macros[1], macros[2]))

            if other_technique == technique:
                pt_file = capsule_ckcpoint
                step_ckcpoint = osp.split(pt_file)[0]
                step = int(osp.basename(pt_file).split('_')[-2])
                pairwise = True if 'pairwise' in pt_file else False
                metrics, bestloss = get_test_metric_by_step(step_ckcpoint=step_ckcpoint, steps=step, pairwise=pairwise)
                acc, pre, rec, f1 = metrics['best_val_bceloss']['acc'], metrics['best_val_bceloss']['pre'], metrics['best_val_bceloss']['rec'], metrics['best_val_bceloss']['f1']

                # if abs(round(loss, 4) - round(bestloss, 4)) > 0.001:
                #     print("         Error in loss: {}, {}".format(loss, bestloss))
                #     my_break = True
                if abs(round(mic_acc, 4) - round(acc, 4)) > 0.001:
                    print("         Error in acc: {}, {}".format(mic_acc, acc))
                    my_break = True
                if abs(round(macros[0], 4) - round(pre, 4)) > 0.001:
                    print("         Error in pre: {}, {}".format(macros[0], pre))
                    my_break = True
                if abs(round(macros[1], 4) - round(rec, 4)) > 0.001:
                    print("         Error in rec: {}, {}".format(macros[1], rec))
                    my_break = True
                if abs(round(macros[2], 4) - round(f1, 4)) > 0.001:
                    print("         Error in f1: {}, {}".format(macros[2], f1))
                    my_break = True

                if my_break:
                    break
                    
        if my_break:
            break

    if my_break:
        break
# Out:
#  ==================================== deepfake CHECKPOINT =========================
#
# ************************ So sánh với technique:  deepfake
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_val_loss_12600_1.960673.pt
#         0. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.902600       |  0.902600
#             precision =  0.917092  |   recall =    0.902600   |  f1 =    0.901747
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_val_loss_14000_1.959382.pt
#         4. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.905700       |  0.905700
#             precision =  0.919757  |   recall =    0.905700   |  f1 =    0.904904
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_val_loss_11000_1.959354.pt
#         1. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.893300       |  0.893300
#             precision =  0.911121  |   recall =    0.893300   |  f1 =    0.892131
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_val_loss_15400_1.957669.pt
#         2. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.902900       |  0.902900
#             precision =  0.917760  |   recall =    0.902900   |  f1 =    0.902029
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_val_loss_14400_1.960276.pt
#         3. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.877000       |  0.877000
#             precision =  0.899556  |   recall =    0.877000   |  f1 =    0.875239
#
# ************************ So sánh với technique:  3dmm
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_val_loss_12600_1.960673.pt
#         0. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.554300       |  0.554300
#             precision =  0.746470  |   recall =    0.554300   |  f1 =    0.446389
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_val_loss_14000_1.959382.pt
#         4. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.550500       |  0.550500
#             precision =  0.750203  |   recall =    0.550500   |  f1 =    0.438447
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_val_loss_11000_1.959354.pt
#         1. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.570200       |  0.570200
#             precision =  0.759999  |   recall =    0.570200   |  f1 =    0.474251
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_val_loss_15400_1.957669.pt
#         2. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.534200       |  0.534200
#             precision =  0.739960  |   recall =    0.534200   |  f1 =    0.407101
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_val_loss_14400_1.960276.pt
#         3. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.541400       |  0.541400
#             precision =  0.737818  |   recall =    0.541400   |  f1 =    0.422069
#
# ************************ So sánh với technique:  faceswap_2d
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_val_loss_12600_1.960673.pt
#         0. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.498400       |  0.498400
#             precision =  0.345753  |   recall =    0.498400   |  f1 =    0.333505
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_val_loss_14000_1.959382.pt
#         4. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.499500       |  0.499500
#             precision =  0.445527  |   recall =    0.499500   |  f1 =    0.334702
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_val_loss_11000_1.959354.pt
#         1. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.498900       |  0.498900
#             precision =  0.316391  |   recall =    0.498900   |  f1 =    0.333198
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_val_loss_15400_1.957669.pt
#         2. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.499000       |  0.499000
#             precision =  0.360861  |   recall =    0.499000   |  f1 =    0.333596
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_val_loss_14400_1.960276.pt
#         3. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.498400       |  0.498400
#             precision =  0.345753  |   recall =    0.498400   |  f1 =    0.333505
#
# ************************ So sánh với technique:  faceswap_3d
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_val_loss_12600_1.960673.pt
#         0. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.497900       |  0.497900
#             precision =  0.249474  |   recall =    0.497900   |  f1 =    0.332399
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_val_loss_14000_1.959382.pt
#         4. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.498600       |  0.498600
#             precision =  0.249650  |   recall =    0.498600   |  f1 =    0.332711
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_val_loss_11000_1.959354.pt
#         1. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.498700       |  0.498700
#             precision =  0.249675  |   recall =    0.498700   |  f1 =    0.332755
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_val_loss_15400_1.957669.pt
#         2. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.498600       |  0.498600
#             precision =  0.249650  |   recall =    0.498600   |  f1 =    0.332711
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_val_loss_14400_1.960276.pt
#         3. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.497900       |  0.497900
#             precision =  0.249474  |   recall =    0.497900   |  f1 =    0.332399
#
# ************************ So sánh với technique:  monkey
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_val_loss_12600_1.960673.pt
#         0. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.503100       |  0.503100
#             precision =  0.606945  |   recall =    0.503100   |  f1 =    0.343807
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_val_loss_14000_1.959382.pt
#         4. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.502400       |  0.502400
#             precision =  0.615988  |   recall =    0.502400   |  f1 =    0.341078
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_val_loss_11000_1.959354.pt
#         1. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.503400       |  0.503400
#             precision =  0.642522  |   recall =    0.503400   |  f1 =    0.343090
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_val_loss_15400_1.957669.pt
#         2. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.503300       |  0.503300
#             precision =  0.636076  |   recall =    0.503300   |  f1 =    0.343044
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_val_loss_14400_1.960276.pt
#         3. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.504500       |  0.504500
#             precision =  0.630445  |   recall =    0.504500   |  f1 =    0.346844
#
# ************************ So sánh với technique:  reenact
# Test image dataset:  9566
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_val_loss_12600_1.960673.pt
#         0. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.703533       |  0.703461
#             precision =  0.813487  |   recall =    0.689643   |  f1 =    0.665437
# Test image dataset:  9566
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_val_loss_14000_1.959382.pt
#         4. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.669036       |  0.668971
#             precision =  0.801439  |   recall =    0.653440   |  f1 =    0.615412
# Test image dataset:  9566
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_val_loss_11000_1.959354.pt
#         1. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.560004       |  0.559887
#             precision =  0.754563  |   recall =    0.539217   |  f1 =    0.426381
# Test image dataset:  9566
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_val_loss_15400_1.957669.pt
#         2. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.558541       |  0.558424
#             precision =  0.752258  |   recall =    0.537693   |  f1 =    0.423562
# Test image dataset:  9566
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_val_loss_14400_1.960276.pt
#         3. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.603178       |  0.603067
#             precision =  0.771453  |   recall =    0.584518   |  f1 =    0.509084
#
# ************************ So sánh với technique:  stargan
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_val_loss_12600_1.960673.pt
#         0. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.500800       |  0.500800
#             precision =  0.540201  |   recall =    0.500800   |  f1 =    0.338786
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_val_loss_14000_1.959382.pt
#         4. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.498600       |  0.498600
#             precision =  0.249650  |   recall =    0.498600   |  f1 =    0.332711
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_val_loss_11000_1.959354.pt
#         1. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.502500       |  0.502500
#             precision =  0.623177  |   recall =    0.502500   |  f1 =    0.341124
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_val_loss_15400_1.957669.pt
#         2. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.500700       |  0.500700
#             precision =  0.550176  |   recall =    0.500700   |  f1 =    0.337348
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_val_loss_14400_1.960276.pt
#         3. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.498500       |  0.498500
#             precision =  0.360735  |   recall =    0.498500   |  f1 =    0.333725
#
# ************************ So sánh với technique:  x2face
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_val_loss_12600_1.960673.pt
#         0. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.766500       |  0.766500
#             precision =  0.837476  |   recall =    0.766500   |  f1 =    0.753542
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_val_loss_14000_1.959382.pt
#         4. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.743400       |  0.743400
#             precision =  0.827881  |   recall =    0.743400   |  f1 =    0.725733
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_val_loss_11000_1.959354.pt
#         1. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.778500       |  0.778500
#             precision =  0.844537  |   recall =    0.778500   |  f1 =    0.767352
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_val_loss_15400_1.957669.pt
#         2. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.773800       |  0.773800
#             precision =  0.842092  |   recall =    0.773800   |  f1 =    0.761918
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_val_loss_14400_1.960276.pt
#         3. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.756800       |  0.756800
#             precision =  0.832851  |   recall =    0.756800   |  f1 =    0.742067
#
#
#  ==================================== 3dmm CHECKPOINT =========================
#
# ************************ So sánh với technique:  deepfake
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_val_loss_11400_1.957383.pt
#         2. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.600600       |  0.600600
#             precision =  0.776500  |   recall =    0.600600   |  f1 =    0.525066
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_val_loss_14400_1.956999.pt
#         1. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.583800       |  0.583800
#             precision =  0.771104  |   recall =    0.583800   |  f1 =    0.496903
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_val_loss_13200_1.959011.pt
#         4. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.562700       |  0.562700
#             precision =  0.765146  |   recall =    0.562700   |  f1 =    0.459535
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_val_loss_14200_1.959777.pt
#         0. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.642700       |  0.642700
#             precision =  0.788255  |   recall =    0.642700   |  f1 =    0.591079
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_val_loss_13600_1.956975.pt
#         3. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.634600       |  0.634600
#             precision =  0.787443  |   recall =    0.634600   |  f1 =    0.578579
#
# ************************ So sánh với technique:  3dmm
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_val_loss_11400_1.957383.pt
#         2. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.996300       |  0.996300
#             precision =  0.996319  |   recall =    0.996300   |  f1 =    0.996300
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_val_loss_14400_1.956999.pt
#         1. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.999100       |  0.999100
#             precision =  0.999100  |   recall =    0.999100   |  f1 =    0.999100
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_val_loss_13200_1.959011.pt
#         4. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.998000       |  0.998000
#             precision =  0.998005  |   recall =    0.998000   |  f1 =    0.998000
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_val_loss_14200_1.959777.pt
#         0. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.998300       |  0.998300
#             precision =  0.998300  |   recall =    0.998300   |  f1 =    0.998300
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_val_loss_13600_1.956975.pt
#         3. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.998900       |  0.998900
#             precision =  0.998900  |   recall =    0.998900   |  f1 =    0.998900
#
# ************************ So sánh với technique:  faceswap_2d
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_val_loss_11400_1.957383.pt
#         2. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.499700       |  0.499700
#             precision =  0.249925  |   recall =    0.499700   |  f1 =    0.333200
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_val_loss_14400_1.956999.pt
#         1. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.499900       |  0.499900
#             precision =  0.449975  |   recall =    0.499900   |  f1 =    0.333644
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_val_loss_13200_1.959011.pt
#         4. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.500500       |  0.500500
#             precision =  0.639014  |   recall =    0.500500   |  f1 =    0.334798
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_val_loss_14200_1.959777.pt
#         0. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.500500       |  0.500500
#             precision =  0.550125  |   recall =    0.500500   |  f1 =    0.336207
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_val_loss_13600_1.956975.pt
#         3. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.500700       |  0.500700
#             precision =  0.616842  |   recall =    0.500700   |  f1 =    0.335593
#
# ************************ So sánh với technique:  faceswap_3d
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_val_loss_11400_1.957383.pt
#         2. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.499700       |  0.499700
#             precision =  0.249925  |   recall =    0.499700   |  f1 =    0.333200
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_val_loss_14400_1.956999.pt
#         1. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.499800       |  0.499800
#             precision =  0.374950  |   recall =    0.499800   |  f1 =    0.333422
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_val_loss_13200_1.959011.pt
#         4. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.499900       |  0.499900
#             precision =  0.416642  |   recall =    0.499900   |  f1 =    0.333467
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_val_loss_14200_1.959777.pt
#         0. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.499300       |  0.499300
#             precision =  0.365209  |   recall =    0.499300   |  f1 =    0.333554
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_val_loss_13600_1.956975.pt
#         3. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.500100       |  0.500100
#             precision =  0.527803  |   recall =    0.500100   |  f1 =    0.334265
#
# ************************ So sánh với technique:  monkey
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_val_loss_11400_1.957383.pt
#         2. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.500800       |  0.500800
#             precision =  0.643057  |   recall =    0.500800   |  f1 =    0.335638
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_val_loss_14400_1.956999.pt
#         1. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.500300       |  0.500300
#             precision =  0.583408  |   recall =    0.500300   |  f1 =    0.334531
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_val_loss_13200_1.959011.pt
#         4. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.502200       |  0.502200
#             precision =  0.712090  |   recall =    0.502200   |  f1 =    0.338554
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_val_loss_14200_1.959777.pt
#         0. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.502800       |  0.502800
#             precision =  0.646537  |   recall =    0.502800   |  f1 =    0.341262
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_val_loss_13600_1.956975.pt
#         3. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.503200       |  0.503200
#             precision =  0.700803  |   recall =    0.503200   |  f1 =    0.341100
#
# ************************ So sánh với technique:  reenact
# Test image dataset:  9566
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_val_loss_11400_1.957383.pt
#         2. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.594188       |  0.594138
#             precision =  0.779315  |   recall =    0.574930   |  f1 =    0.490826
# Test image dataset:  9566
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_val_loss_14400_1.956999.pt
#         1. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.623249       |  0.623208
#             precision =  0.789041  |   recall =    0.605372   |  f1 =    0.541857
# Test image dataset:  9566
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_val_loss_13200_1.959011.pt
#         4. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.765628       |  0.765603
#             precision =  0.844832  |   recall =    0.754509   |  f1 =    0.745795
# Test image dataset:  9566
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_val_loss_14200_1.959777.pt
#         0. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.716914       |  0.716943
#             precision =  0.821869  |   recall =    0.703555   |  f1 =    0.683167
# Test image dataset:  9566
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_val_loss_13600_1.956975.pt
#         3. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.833995       |  0.834000
#             precision =  0.878965  |   recall =    0.826144   |  f1 =    0.826296
#
# ************************ So sánh với technique:  stargan
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_val_loss_11400_1.957383.pt
#         2. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.499700       |  0.499700
#             precision =  0.249925  |   recall =    0.499700   |  f1 =    0.333200
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_val_loss_14400_1.956999.pt
#         1. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.501700       |  0.501700
#             precision =  0.685209  |   recall =    0.501700   |  f1 =    0.337627
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_val_loss_13200_1.959011.pt
#         4. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.502200       |  0.502200
#             precision =  0.712090  |   recall =    0.502200   |  f1 =    0.338554
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_val_loss_14200_1.959777.pt
#         0. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.499900       |  0.499900
#             precision =  0.486817  |   recall =    0.499900   |  f1 =    0.334882
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_val_loss_13600_1.956975.pt
#         3. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.500300       |  0.500300
#             precision =  0.568257  |   recall =    0.500300   |  f1 =    0.334708
#
# ************************ So sánh với technique:  x2face
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_val_loss_11400_1.957383.pt
#         2. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.577400       |  0.577400
#             precision =  0.769064  |   recall =    0.577400   |  f1 =    0.485836
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_val_loss_14400_1.956999.pt
#         1. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.579400       |  0.579400
#             precision =  0.769701  |   recall =    0.579400   |  f1 =    0.489315
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_val_loss_13200_1.959011.pt
#         4. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.592400       |  0.592400
#             precision =  0.774385  |   recall =    0.592400   |  f1 =    0.511381
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_val_loss_14200_1.959777.pt
#         0. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.601800       |  0.601800
#             precision =  0.773581  |   recall =    0.601800   |  f1 =    0.527654
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_val_loss_13600_1.956975.pt
#         3. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.618600       |  0.618600
#             precision =  0.781995  |   recall =    0.618600   |  f1 =    0.553993
#
#
#  ==================================== faceswap_2d CHECKPOINT =========================
#
# ************************ So sánh với technique:  deepfake
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_val_loss_13800_2.039975.pt
#         2. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.500500       |  0.500500
#             precision =  0.565915  |   recall =    0.500500   |  f1 =    0.335680
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_val_loss_14600_2.042029.pt
#         1. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.500600       |  0.500600
#             precision =  0.593900  |   recall =    0.500600   |  f1 =    0.335549
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_val_loss_12400_2.064626.pt
#         3. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.498700       |  0.498700
#             precision =  0.344912  |   recall =    0.498700   |  f1 =    0.333462
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_val_loss_11000_2.037353.pt
#         0. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.502000       |  0.502000
#             precision =  0.586710  |   recall =    0.502000   |  f1 =    0.341066
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_val_loss_15000_2.040870.pt
#         4. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.499200       |  0.499200
#             precision =  0.437299  |   recall =    0.499200   |  f1 =    0.335095
#
# ************************ So sánh với technique:  3dmm
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_val_loss_13800_2.039975.pt
#         2. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.505300       |  0.505300
#             precision =  0.699095  |   recall =    0.505300   |  f1 =    0.346201
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_val_loss_14600_2.042029.pt
#         1. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.512600       |  0.512600
#             precision =  0.734811  |   recall =    0.512600   |  f1 =    0.361553
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_val_loss_12400_2.064626.pt
#         3. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.522700       |  0.522700
#             precision =  0.723260  |   recall =    0.522700   |  f1 =    0.384462
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_val_loss_11000_2.037353.pt
#         0. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.509900       |  0.509900
#             precision =  0.683166  |   recall =    0.509900   |  f1 =    0.358098
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_val_loss_15000_2.040870.pt
#         4. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.509600       |  0.509600
#             precision =  0.678904  |   recall =    0.509600   |  f1 =    0.357623
#
# ************************ So sánh với technique:  faceswap_2d
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_val_loss_13800_2.039975.pt
#         2. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.538500       |  0.538500
#             precision =  0.751253  |   recall =    0.538500   |  f1 =    0.414569
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_val_loss_14600_2.042029.pt
#         1. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.512600       |  0.512600
#             precision =  0.734811  |   recall =    0.512600   |  f1 =    0.361553
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_val_loss_12400_2.064626.pt
#         3. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.558200       |  0.558200
#             precision =  0.751706  |   recall =    0.558200   |  f1 =    0.453086
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_val_loss_11000_2.037353.pt
#         0. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.557900       |  0.557900
#             precision =  0.750030  |   recall =    0.557900   |  f1 =    0.452774
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_val_loss_15000_2.040870.pt
#         4. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.562300       |  0.562300
#             precision =  0.751598  |   recall =    0.562300   |  f1 =    0.460897
#
# ************************ So sánh với technique:  faceswap_3d
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_val_loss_13800_2.039975.pt
#         2. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.501100       |  0.501100
#             precision =  0.610276  |   recall =    0.501100   |  f1 =    0.337004
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_val_loss_14600_2.042029.pt
#         1. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.500100       |  0.500100
#             precision =  0.522752  |   recall =    0.500100   |  f1 =    0.334442
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_val_loss_12400_2.064626.pt
#         3. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.503400       |  0.503400
#             precision =  0.625856  |   recall =    0.503400   |  f1 =    0.343776
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_val_loss_11000_2.037353.pt
#         0. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.501600       |  0.501600
#             precision =  0.574476  |   recall =    0.501600   |  f1 =    0.340192
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_val_loss_15000_2.040870.pt
#         4. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.504900       |  0.504900
#             precision =  0.638876  |   recall =    0.504900   |  f1 =    0.347540
#
# ************************ So sánh với technique:  monkey
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_val_loss_13800_2.039975.pt
#         2. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.499300       |  0.499300
#             precision =  0.249825  |   recall =    0.499300   |  f1 =    0.333022
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_val_loss_14600_2.042029.pt
#         1. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.499600       |  0.499600
#             precision =  0.333233  |   recall =    0.499600   |  f1 =    0.333333
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_val_loss_12400_2.064626.pt
#         3. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.498400       |  0.498400
#             precision =  0.277377  |   recall =    0.498400   |  f1 =    0.332798
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_val_loss_11000_2.037353.pt
#         0. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.498100       |  0.498100
#             precision =  0.249524  |   recall =    0.498100   |  f1 =    0.332488
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_val_loss_15000_2.040870.pt
#         4. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.498700       |  0.498700
#             precision =  0.379304  |   recall =    0.498700   |  f1 =    0.333991
#
# ************************ So sánh với technique:  reenact
# Test image dataset:  9566
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_val_loss_13800_2.039975.pt
#         2. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.521953       |  0.521844
#             precision =  0.261167  |   recall =    0.499300   |  f1 =    0.342949
# Test image dataset:  9566
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_val_loss_14600_2.042029.pt
#         1. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.524148       |  0.524038
#             precision =  0.657571  |   recall =    0.501581   |  f1 =    0.347627
# Test image dataset:  9566
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_val_loss_12400_2.064626.pt
#         3. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.567531       |  0.567487
#             precision =  0.755342  |   recall =    0.547139   |  f1 =    0.442015
# Test image dataset:  9566
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_val_loss_11000_2.037353.pt
#         0. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.521326       |  0.521217
#             precision =  0.381031  |   recall =    0.498757   |  f1 =    0.343856
# Test image dataset:  9566
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_val_loss_15000_2.040870.pt
#         4. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.536170       |  0.536058
#             precision =  0.705807  |   recall =    0.514316   |  f1 =    0.377373
#
# ************************ So sánh với technique:  stargan
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_val_loss_13800_2.039975.pt
#         2. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.513500       |  0.513500
#             precision =  0.729936  |   recall =    0.513500   |  f1 =    0.363784
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_val_loss_14600_2.042029.pt
#         1. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.513100       |  0.513100
#             precision =  0.735591  |   recall =    0.513100   |  f1 =    0.362614
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_val_loss_12400_2.064626.pt
#         3. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.504900       |  0.504900
#             precision =  0.648826  |   recall =    0.504900   |  f1 =    0.347033
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_val_loss_11000_2.037353.pt
#         0. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.513100       |  0.513100
#             precision =  0.697118  |   recall =    0.513100   |  f1 =    0.364870
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_val_loss_15000_2.040870.pt
#         4. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.507800       |  0.507800
#             precision =  0.667228  |   recall =    0.507800   |  f1 =    0.353781
#
# ************************ So sánh với technique:  x2face
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_val_loss_13800_2.039975.pt
#         2. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.500700       |  0.500700
#             precision =  0.583509  |   recall =    0.500700   |  f1 =    0.336122
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_val_loss_14600_2.042029.pt
#         1. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.500000       |  0.500000
#             precision =  0.500000  |   recall =    0.500000   |  f1 =    0.334220
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_val_loss_12400_2.064626.pt
#         3. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.501500       |  0.501500
#             precision =  0.576907  |   recall =    0.501500   |  f1 =    0.339627
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_val_loss_11000_2.037353.pt
#         0. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.502100       |  0.502100
#             precision =  0.589511  |   recall =    0.502100   |  f1 =    0.341285
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_val_loss_15000_2.040870.pt
#         4. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.501400       |  0.501400
#             precision =  0.565167  |   recall =    0.501400   |  f1 =    0.339927
#
#
#  ==================================== faceswap_3d CHECKPOINT =========================
#
# ************************ So sánh với technique:  deepfake
# Test image dataset:  10000
#             pt file:  (2.0353_0.5974_0.7937)_fold_3/step/bestcapsule_val_loss_14200_2.035321.pt
#         3. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.497900       |  0.497900
#             precision =  0.271213  |   recall =    0.497900   |  f1 =    0.332575
# Test image dataset:  10000
#             pt file:  (2.0435_0.5569_0.7759)_fold_2/step/bestcapsule_val_loss_14000_2.043468.pt
#         2. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.501500       |  0.501500
#             precision =  0.596530  |   recall =    0.501500   |  f1 =    0.338758
# Test image dataset:  10000
#             pt file:  (2.0289_0.6418_0.8168)_fold_4/step/bestcapsule_val_loss_13600_2.028886.pt
#         4. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.499600       |  0.499600
#             precision =  0.477172  |   recall =    0.499600   |  f1 =    0.336674
# Test image dataset:  10000
#             pt file:  (2.0324_0.5335_0.7618)_fold_1/step/bestcapsule_val_loss_11400_2.032441.pt
#         1. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.499900       |  0.499900
#             precision =  0.472197  |   recall =    0.499900   |  f1 =    0.333998
# Test image dataset:  10000
#             pt file:  (2.0264_0.5584_0.8305)_fold_0/step/bestcapsule_val_loss_12400_2.026355.pt
#         0. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.499000       |  0.499000
#             precision =  0.249750  |   recall =    0.499000   |  f1 =    0.332889
#
# ************************ So sánh với technique:  3dmm
# Test image dataset:  10000
#             pt file:  (2.0353_0.5974_0.7937)_fold_3/step/bestcapsule_val_loss_14200_2.035321.pt
#         3. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.508900       |  0.508900
#             precision =  0.669548  |   recall =    0.508900   |  f1 =    0.356460
# Test image dataset:  10000
#             pt file:  (2.0435_0.5569_0.7759)_fold_2/step/bestcapsule_val_loss_14000_2.043468.pt
#         2. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.507000       |  0.507000
#             precision =  0.687937  |   recall =    0.507000   |  f1 =    0.350728
# Test image dataset:  10000
#             pt file:  (2.0289_0.6418_0.8168)_fold_4/step/bestcapsule_val_loss_13600_2.028886.pt
#         4. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.520600       |  0.520600
#             precision =  0.708040  |   recall =    0.520600   |  f1 =    0.381224
# Test image dataset:  10000
#             pt file:  (2.0324_0.5335_0.7618)_fold_1/step/bestcapsule_val_loss_11400_2.032441.pt
#         1. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.503900       |  0.503900
#             precision =  0.699959  |   recall =    0.503900   |  f1 =    0.342806
# Test image dataset:  10000
#             pt file:  (2.0264_0.5584_0.8305)_fold_0/step/bestcapsule_val_loss_12400_2.026355.pt
#         0. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.503200       |  0.503200
#             precision =  0.654650  |   recall =    0.503200   |  f1 =    0.342137
#
# ************************ So sánh với technique:  faceswap_2d
# Test image dataset:  10000
#             pt file:  (2.0353_0.5974_0.7937)_fold_3/step/bestcapsule_val_loss_14200_2.035321.pt
#         3. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.522700       |  0.522700
#             precision =  0.715243  |   recall =    0.522700   |  f1 =    0.385212
# Test image dataset:  10000
#             pt file:  (2.0435_0.5569_0.7759)_fold_2/step/bestcapsule_val_loss_14000_2.043468.pt
#         2. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.510700       |  0.510700
#             precision =  0.706909  |   recall =    0.510700   |  f1 =    0.358655
# Test image dataset:  10000
#             pt file:  (2.0289_0.6418_0.8168)_fold_4/step/bestcapsule_val_loss_13600_2.028886.pt
#         4. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.539700       |  0.539700
#             precision =  0.733421  |   recall =    0.539700   |  f1 =    0.419194
# Test image dataset:  10000
#             pt file:  (2.0324_0.5335_0.7618)_fold_1/step/bestcapsule_val_loss_11400_2.032441.pt
#         1. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.507500       |  0.507500
#             precision =  0.722479  |   recall =    0.507500   |  f1 =    0.350630
# Test image dataset:  10000
#             pt file:  (2.0264_0.5584_0.8305)_fold_0/step/bestcapsule_val_loss_12400_2.026355.pt
#         0. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.526500       |  0.526500
#             precision =  0.739275  |   recall =    0.526500   |  f1 =    0.391144
#
# ************************ So sánh với technique:  faceswap_3d
# Test image dataset:  10000
#             pt file:  (2.0353_0.5974_0.7937)_fold_3/step/bestcapsule_val_loss_14200_2.035321.pt
#         3. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.597400       |  0.597400
#             precision =  0.766304  |   recall =    0.597400   |  f1 =    0.521533
# Test image dataset:  10000
#             pt file:  (2.0435_0.5569_0.7759)_fold_2/step/bestcapsule_val_loss_14000_2.043468.pt
#         2. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.556900       |  0.556900
#             precision =  0.755004  |   recall =    0.556900   |  f1 =    0.450100
# Test image dataset:  10000
#             pt file:  (2.0289_0.6418_0.8168)_fold_4/step/bestcapsule_val_loss_13600_2.028886.pt
#         4. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.641800       |  0.641800
#             precision =  0.783354  |   recall =    0.641800   |  f1 =    0.590679
# Test image dataset:  10000
#             pt file:  (2.0324_0.5335_0.7618)_fold_1/step/bestcapsule_val_loss_11400_2.032441.pt
#         1. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.533500       |  0.533500
#             precision =  0.751428  |   recall =    0.533500   |  f1 =    0.404450
# Test image dataset:  10000
#             pt file:  (2.0264_0.5584_0.8305)_fold_0/step/bestcapsule_val_loss_12400_2.026355.pt
#         0. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.558400       |  0.558400
#             precision =  0.757260  |   recall =    0.558400   |  f1 =    0.452620
#
# ************************ So sánh với technique:  monkey
# Test image dataset:  10000
#             pt file:  (2.0353_0.5974_0.7937)_fold_3/step/bestcapsule_val_loss_14200_2.035321.pt
#         3. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.499500       |  0.499500
#             precision =  0.467823  |   recall =    0.499500   |  f1 =    0.336105
# Test image dataset:  10000
#             pt file:  (2.0435_0.5569_0.7759)_fold_2/step/bestcapsule_val_loss_14000_2.043468.pt
#         2. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.499300       |  0.499300
#             precision =  0.396884  |   recall =    0.499300   |  f1 =    0.333907
# Test image dataset:  10000
#             pt file:  (2.0289_0.6418_0.8168)_fold_4/step/bestcapsule_val_loss_13600_2.028886.pt
#         4. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.499800       |  0.499800
#             precision =  0.489080  |   recall =    0.499800   |  f1 =    0.337114
# Test image dataset:  10000
#             pt file:  (2.0324_0.5335_0.7618)_fold_1/step/bestcapsule_val_loss_11400_2.032441.pt
#         1. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.500000       |  0.500000
#             precision =  0.500000  |   recall =    0.500000   |  f1 =    0.334220
# Test image dataset:  10000
#             pt file:  (2.0264_0.5584_0.8305)_fold_0/step/bestcapsule_val_loss_12400_2.026355.pt
#         0. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.499200       |  0.499200
#             precision =  0.333133  |   recall =    0.499200   |  f1 =    0.333332
#
# ************************ So sánh với technique:  reenact
# Test image dataset:  9566
#             pt file:  (2.0353_0.5974_0.7937)_fold_3/step/bestcapsule_val_loss_14200_2.035321.pt
#         3. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.552687       |  0.552601
#             precision =  0.736286  |   recall =    0.531637   |  f1 =    0.412801
# Test image dataset:  9566
#             pt file:  (2.0435_0.5569_0.7759)_fold_2/step/bestcapsule_val_loss_14000_2.043468.pt
#         2. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.521430       |  0.521321
#             precision =  0.261042  |   recall =    0.498800   |  f1 =    0.342724
# Test image dataset:  9566
# ...
#             accuracy =   0.989200       |  0.989200
#             precision =  0.989205  |   recall =    0.989200   |  f1 =    0.989200
# Test image dataset:  10000
#             pt file:  (1.9669_0.9911_0.9923)_fold_1/step/bestcapsule_val_loss_15000_1.966901.pt
#         1. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.991100       |  0.991100
#             precision =  0.991100  |   recall =    0.991100   |  f1 =    0.991100
# Test image dataset:  10000
#             pt file:  (1.9639_0.9912_0.9945)_fold_4/step/bestcapsule_val_loss_13600_1.963881.pt
#         4. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.991200       |  0.991200
#             precision =  0.991211  |   recall =    0.991200   |  f1 =    0.991200
# Test image dataset:  10000
#             pt file:  (1.9713_0.9897_0.9897)_fold_3/step/bestcapsule_val_loss_13200_1.971310.pt
#         3. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.989700       |  0.989700
#             precision =  0.989700  |   recall =    0.989700   |  f1 =    0.989700
# Test image dataset:  10000
#             pt file:  (1.9646_0.9949_0.9949)_fold_0/step/bestcapsule_val_loss_12600_1.964586.pt
#         0. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.994900       |  0.994900
#             precision =  0.994917  |   recall =    0.994900   |  f1 =    0.994900
#
# ************************ So sánh với technique:  x2face
# Test image dataset:  10000
#             pt file:  (1.9683_0.9892_0.9923)_fold_2/step/bestcapsule_val_loss_13400_1.968295.pt
#         2. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.519900       |  0.519900
#             precision =  0.676086  |   recall =    0.519900   |  f1 =    0.383106
# Test image dataset:  10000
#             pt file:  (1.9669_0.9911_0.9923)_fold_1/step/bestcapsule_val_loss_15000_1.966901.pt
#         1. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.525400       |  0.525400
#             precision =  0.690104  |   recall =    0.525400   |  f1 =    0.394181
# Test image dataset:  10000
#             pt file:  (1.9639_0.9912_0.9945)_fold_4/step/bestcapsule_val_loss_13600_1.963881.pt
#         4. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.516900       |  0.516900
#             precision =  0.685656  |   recall =    0.516900   |  f1 =    0.374836
# Test image dataset:  10000
#             pt file:  (1.9713_0.9897_0.9897)_fold_3/step/bestcapsule_val_loss_13200_1.971310.pt
#         3. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.518400       |  0.518400
#             precision =  0.666706  |   recall =    0.518400   |  f1 =    0.380653
# Test image dataset:  10000
#             pt file:  (1.9646_0.9949_0.9949)_fold_0/step/bestcapsule_val_loss_12600_1.964586.pt
#         0. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.563700       |  0.563700
#             precision =  0.739261  |   recall =    0.563700   |  f1 =    0.465685
#
#
#  ==================================== x2face CHECKPOINT =========================
#
# ************************ So sánh với technique:  deepfake
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_val_loss_13200_1.975642.pt
#         1. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.953700       |  0.953700
#             precision =  0.953710  |   recall =    0.953700   |  f1 =    0.953700
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_val_loss_14200_1.986627.pt
#         3. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.944500       |  0.944500
#             precision =  0.944500  |   recall =    0.944500   |  f1 =    0.944500
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_val_loss_14200_1.984492.pt
#         2. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.940800       |  0.940800
#             precision =  0.942752  |   recall =    0.940800   |  f1 =    0.940735
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_val_loss_14600_1.981361.pt
#         4. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.931700       |  0.931700
#             precision =  0.933577  |   recall =    0.931700   |  f1 =    0.931626
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_val_loss_13000_1.975054.pt
#         0. FOLD: 0    -   cross with dataset: deepfake
#             accuracy =   0.940500       |  0.940500
#             precision =  0.940659  |   recall =    0.940500   |  f1 =    0.940495
#
# ************************ So sánh với technique:  3dmm
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_val_loss_13200_1.975642.pt
#         1. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.802500       |  0.802500
#             precision =  0.833977  |   recall =    0.802500   |  f1 =    0.797734
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_val_loss_14200_1.986627.pt
#         3. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.831700       |  0.831700
#             precision =  0.849521  |   recall =    0.831700   |  f1 =    0.829527
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_val_loss_14200_1.984492.pt
#         2. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.722200       |  0.722200
#             precision =  0.797701  |   recall =    0.722200   |  f1 =    0.703394
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_val_loss_14600_1.981361.pt
#         4. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.722100       |  0.722100
#             precision =  0.790412  |   recall =    0.722100   |  f1 =    0.704737
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_val_loss_13000_1.975054.pt
#         0. FOLD: 1    -   cross with dataset: 3dmm
#             accuracy =   0.762800       |  0.762800
#             precision =  0.805644  |   recall =    0.762800   |  f1 =    0.754186
#
# ************************ So sánh với technique:  faceswap_2d
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_val_loss_13200_1.975642.pt
#         1. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.498500       |  0.498500
#             precision =  0.490785  |   recall =    0.498500   |  f1 =    0.365747
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_val_loss_14200_1.986627.pt
#         3. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.502900       |  0.502900
#             precision =  0.513206  |   recall =    0.502900   |  f1 =    0.382409
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_val_loss_14200_1.984492.pt
#         2. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.497700       |  0.497700
#             precision =  0.475149  |   recall =    0.497700   |  f1 =    0.350310
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_val_loss_14600_1.981361.pt
#         4. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.497400       |  0.497400
#             precision =  0.479511  |   recall =    0.497400   |  f1 =    0.357062
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_val_loss_13000_1.975054.pt
#         0. FOLD: 2    -   cross with dataset: faceswap_2d
#             accuracy =   0.494300       |  0.494300
#             precision =  0.466342  |   recall =    0.494300   |  f1 =    0.361762
#
# ************************ So sánh với technique:  faceswap_3d
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_val_loss_13200_1.975642.pt
#         1. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.490800       |  0.490800
#             precision =  0.431525  |   recall =    0.490800   |  f1 =    0.350170
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_val_loss_14200_1.986627.pt
#         3. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.497400       |  0.497400
#             precision =  0.487003  |   recall =    0.497400   |  f1 =    0.371760
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_val_loss_14200_1.984492.pt
#         2. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.492300       |  0.492300
#             precision =  0.392848  |   recall =    0.492300   |  f1 =    0.338902
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_val_loss_14600_1.981361.pt
#         4. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.494500       |  0.494500
#             precision =  0.452596  |   recall =    0.494500   |  f1 =    0.351096
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_val_loss_13000_1.975054.pt
#         0. FOLD: 3    -   cross with dataset: faceswap_3d
#             accuracy =   0.497400       |  0.497400
#             precision =  0.485605  |   recall =    0.497400   |  f1 =    0.367921
#
# ************************ So sánh với technique:  monkey
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_val_loss_13200_1.975642.pt
#         1. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.561000       |  0.561000
#             precision =  0.662277  |   recall =    0.561000   |  f1 =    0.479842
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_val_loss_14200_1.986627.pt
#         3. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.569300       |  0.569300
#             precision =  0.658727  |   recall =    0.569300   |  f1 =    0.498691
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_val_loss_14200_1.984492.pt
#         2. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.555500       |  0.555500
#             precision =  0.685352  |   recall =    0.555500   |  f1 =    0.461119
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_val_loss_14600_1.981361.pt
#         4. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.552700       |  0.552700
#             precision =  0.663994  |   recall =    0.552700   |  f1 =    0.461304
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_val_loss_13000_1.975054.pt
#         0. FOLD: 4    -   cross with dataset: monkey
#             accuracy =   0.571200       |  0.571200
#             precision =  0.667120  |   recall =    0.571200   |  f1 =    0.499364
#
# ************************ So sánh với technique:  reenact
# Test image dataset:  9566
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_val_loss_13200_1.975642.pt
#         1. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.976584       |  0.976589
#             precision =  0.976579  |   recall =    0.977562   |  f1 =    0.976572
# Test image dataset:  9566
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_val_loss_14200_1.986627.pt
#         3. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.970102       |  0.970109
#             precision =  0.970398  |   recall =    0.971314   |  f1 =    0.970093
# Test image dataset:  9566
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_val_loss_14200_1.984492.pt
#         2. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.865356       |  0.865325
#             precision =  0.885576  |   recall =    0.860193   |  f1 =    0.862136
# Test image dataset:  9566
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_val_loss_14600_1.981361.pt
#         4. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.924002       |  0.924018
#             precision =  0.927712  |   recall =    0.922072   |  f1 =    0.923457
# Test image dataset:  9566
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_val_loss_13000_1.975054.pt
#         0. FOLD: 5    -   cross with dataset: reenact
#             accuracy =   0.970416       |  0.970422
#             precision =  0.970416  |   recall =    0.971386   |  f1 =    0.970401
#
# ************************ So sánh với technique:  stargan
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_val_loss_13200_1.975642.pt
#         1. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.489300       |  0.489300
#             precision =  0.416903  |   recall =    0.489300   |  f1 =    0.347091
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_val_loss_14200_1.986627.pt
#         3. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.510700       |  0.510700
#             precision =  0.543333  |   recall =    0.510700   |  f1 =    0.397214
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_val_loss_14200_1.984492.pt
#         2. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.512700       |  0.512700
#             precision =  0.585344  |   recall =    0.512700   |  f1 =    0.380972
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_val_loss_14600_1.981361.pt
#         4. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.525500       |  0.525500
#             precision =  0.611468  |   recall =    0.525500   |  f1 =    0.412159
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_val_loss_13000_1.975054.pt
#         0. FOLD: 6    -   cross with dataset: stargan
#             accuracy =   0.518900       |  0.518900
#             precision =  0.573652  |   recall =    0.518900   |  f1 =    0.409079
#
# ************************ So sánh với technique:  x2face
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_val_loss_13200_1.975642.pt
#         1. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.976000       |  0.976000
#             precision =  0.976763  |   recall =    0.976000   |  f1 =    0.975990
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_val_loss_14200_1.986627.pt
#         3. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.969300       |  0.969300
#             precision =  0.970448  |   recall =    0.969300   |  f1 =    0.969281
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_val_loss_14200_1.984492.pt
#         2. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.982300       |  0.982300
#             precision =  0.982433  |   recall =    0.982300   |  f1 =    0.982299
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_val_loss_14600_1.981361.pt
#         4. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.978000       |  0.978000
#             precision =  0.978344  |   recall =    0.978000   |  f1 =    0.977996
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_val_loss_13000_1.975054.pt
#         0. FOLD: 7    -   cross with dataset: x2face
#             accuracy =   0.973800       |  0.973800
#             precision =  0.974876  |   recall =    0.973800   |  f1 =    0.973785
