# %%
from model.cnn.xception_net.model import xception
from model.cnn.mesonet4.model import mesonet
import torch
from module.train_torch import calculate_metric
import random
import numpy as np
import os
import torch.nn as nn
from glob import glob
from tqdm import tqdm
from os.path import join
from utils.util import get_test_metric_by_step2
from operator import truediv
import os, sys
from random import shuffle
import os.path as osp

import torch
from torchvision import datasets, transforms

from dataloader.utils import make_weights_for_balanced_classes, make_weights_for_balanced_classes_2
from dataloader.dual_fft_dataset import DualFFTMagnitudeFeatureDataset, DualFFTMagnitudeImageDataset, TripleFFTMagnitudePhaseDataset
from dataloader.pairwise_dual_fft_dataset import PairwiseDualFFTMagnitudeFeatureDataset, PairwiseDualFFTMagnitudeImageDataset
from dataloader.pairwise_single_fft_dataset import PairwiseSingleFFTMagnitudeImageDataset
from dataloader.pairwise_triple_fft_dataset import PairwiseTripleFFTMagnitudePhaseDataset
from dataloader.triplewise_dual_fft_dataset import TriplewiseDualFFTMagnitudeImageDataset
from dataloader.transform import transform_method

from model.cnn.capsule_net.model import VggExtractor, CapsuleNet
from loss.capsule_loss import CapsuleLoss
from torch.autograd import Variable
from sklearn.metrics import accuracy_score

torch.manual_seed(0)
random.seed(0)
np.random.seed(0)

def eval_kfold_capsulenet(capnet, vgg_ext, dataloader, device, capsule_loss):
    capnet.eval()
    vgg_ext.eval()

    y_label = []
    y_pred = []
    y_pred_label = []
    loss = 0
    mac_accuracy = 0
    
    for inputs, labels in dataloader:
        labels[labels > 1] = 1
        img_label = labels.numpy().astype(np.float)
        inputs, labels = inputs.to(device), labels.to(device)

        input_v = Variable(inputs)
        x = vgg_ext(input_v)
        classes, class_ = capnet(x, random=False)

        loss_dis = capsule_loss(classes, Variable(labels, requires_grad=False))
        loss_dis_data = loss_dis.item()
        output_dis = class_.data.cpu().numpy()

        output_pred = np.zeros((output_dis.shape[0]), dtype=np.float)

        for i in range(output_dis.shape[0]):
            if output_dis[i,1] >= output_dis[i,0]:
                output_pred[i] = 1.0
            else:
                output_pred[i] = 0.0

        loss += loss_dis_data
        y_label.extend(img_label)
        y_pred.extend(output_dis)
        y_pred_label.extend(output_pred)
        mac_accuracy += accuracy_score(img_label, output_pred)
        
    mac_accuracy /= len(dataloader)
    loss /= len(dataloader)
    assert len(y_label) == len(y_pred_label), "Bug"
    ######## Calculate metrics:
    # built-in methods for calculating metrics
    mic_accuracy, reals, fakes, micros, macros = calculate_metric(y_label, y_pred_label)
    return loss, mac_accuracy, mic_accuracy, reals, fakes, micros, macros

def generate_test_dataloader_single_cnn_stream_for_kfold(test_dir, image_size, batch_size, num_workers, adj_brightness=1.0, adj_contrast=1.0):
    transform_fwd = transforms.Compose([transforms.Resize((image_size,image_size)),\
                                        transforms.Lambda(lambda img :transforms.functional.adjust_brightness(img,adj_brightness)),\
                                        transforms.Lambda(lambda img :transforms.functional.adjust_contrast(img,adj_contrast)),\
                                        transforms.ToTensor(),\
                                        transforms.Normalize(mean=[0.485, 0.456, 0.406],\
                                                             std=[0.229, 0.224, 0.225]),\
                                        ])
    # Make dataset using built-in ImageFolder function of torch
    test_dataset = datasets.ImageFolder(test_dir, transform=transform_fwd)
    assert test_dataset, "Test Dataset is empty!"
    print("Test image dataset: ", test_dataset.__len__())
    # Make dataloader
    dataloader_test = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return dataloader_test

################### FROM DEEPFAKE TO OTHER DATASET:
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
device = torch.device('cuda')

test_dir_template = "/mnt/disk1/doan/phucnp/Dataset/my_extend_data/extend_data_train/{}/test"

checkpoints = {
    "deepfake": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/deepfake/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "faceswap_2d": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/faceswap_2d/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "3dmm": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/3dmm/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "faceswap_3d":"/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/faceswap_3d/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "monkey": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/monkey/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "reenact": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/reenact/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "stargan": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/stargan/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0",
    "x2face": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extenddata/x2face/kfold_capsule/lr0.001_batch16_esnone_nf5_trick1_beta0.9_dropout0.05_seed0_drmlp0.0_aug0"
}

brightnesses = [1.0, 0.5, 0.75, 1.5, 2.0]
contrast = 1.0

for brightness in brightnesses:
    print("\n*********************************************************")
    print("             BRIGHTNESS: ", brightness)
    for technique in ['deepfake', '3dmm', 'faceswap_2d', 'faceswap_3d', 'monkey', 'reenact', 'stargan', 'x2face']:
        checkpoint = checkpoints[technique]
        print("\n\n ================ {} CHECKPOINT ================".format(technique))
        my_break = False
        
        for fold_dir in sorted(os.listdir(checkpoint), key=lambda dir: int(dir[-1])):
            pt_file = glob(join(checkpoint, fold_dir, 'step', 'bestcapsule_test_acc*'))[0]

            fold_id = fold_dir[-1]

            vgg_ext = VggExtractor().to(device)
            capnet = CapsuleNet(num_class=2, device=device).to(device)

            capsule_ckcpoint = glob(join(checkpoint, fold_dir, 'step', 'bestcapsule_test_acc*'))[0]
            vggext_ckcpoint = glob(join(checkpoint, fold_dir, 'step', 'bestvgg_test_acc*'))[0]
            vgg_ext.load_state_dict(torch.load(vggext_ckcpoint))
            capnet.load_state_dict(torch.load(capsule_ckcpoint))
            capsule_loss = CapsuleLoss().to(device)
            
            batch_size = 16

            test_dir = test_dir_template.format(technique)
            dataloader_test = generate_test_dataloader_single_cnn_stream_for_kfold(test_dir, 128, batch_size, 4, adj_brightness=brightness, adj_contrast=contrast)

            ####
            loss, mac_acc, mic_acc, reals, fakes, micros, macros = eval_kfold_capsulenet(capnet, vgg_ext, dataloader_test, device, capsule_loss)
            print("            pt file: ", '/'.join(pt_file.split('/')[-3:]))
            print("  FOLD: {}   ".format(fold_id))
            print("            accuracy =   {:.6f}       |  {:6f}".format(mic_acc, mac_acc))
            print("            precision =  {:.6f}  |   recall =    {:.6f}   |  f1 =    {:.6f}".format(macros[0], macros[1], macros[2]))

            if brightness == 1.0:
                step_ckcpoint = osp.split(pt_file)[0]
                step = int(osp.basename(pt_file).split('_')[-2])
                pairwise = True if 'pairwise' in pt_file else False
                metrics, bestloss = get_test_metric_by_step2(step_ckcpoint=step_ckcpoint, steps=step, pairwise=pairwise)
                acc, pre, rec, f1 = metrics['best_test_acc']['acc'], metrics['best_test_acc']['pre'], metrics['best_test_acc']['rec'], metrics['best_test_acc']['f1']

                # if abs(round(loss, 4) - round(bestloss, 4)) > 0.001:
                #     print("         Error in loss: {}, {}".format(loss, bestloss))
                #     my_break = True
                if abs(round(mic_acc, 4) - round(acc, 4)) > 0.001:
                    print("         Error in acc: {}, {}".format(mic_acc, acc))
                    my_break = True
                if abs(round(macros[0], 4) - round(pre, 4)) > 0.001:
                    print("         Error in pre: {}, {}".format(macros[0], pre))
                    my_break = True
                if abs(round(macros[1], 4) - round(rec, 4)) > 0.001:
                    print("         Error in rec: {}, {}".format(macros[1], rec))
                    my_break = True
                if abs(round(macros[2], 4) - round(f1, 4)) > 0.001:
                    print("         Error in f1: {}, {}".format(macros[2], f1))
                    my_break = True

                if my_break:
                    break

        if my_break:
            break

    if my_break:
        break
# Out:
# *********************************************************
#              BRIGHTNESS:  1.0
#
#
#  ================ deepfake CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_test_acc_3000_0.942100.pt
#   FOLD: 0
#             accuracy =   0.942100       |  0.942100
#             precision =  0.944215  |   recall =    0.942100   |  f1 =    0.942031
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_test_acc_11600_0.981000.pt
#   FOLD: 1
#             accuracy =   0.981000       |  0.981000
#             precision =  0.981079  |   recall =    0.981000   |  f1 =    0.980999
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_test_acc_15000_0.955700.pt
#   FOLD: 2
#             accuracy =   0.955700       |  0.955700
#             precision =  0.955792  |   recall =    0.955700   |  f1 =    0.955698
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_test_acc_7000_0.969000.pt
#   FOLD: 3
#             accuracy =   0.969000       |  0.969000
#             precision =  0.969347  |   recall =    0.969000   |  f1 =    0.968994
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_test_acc_9200_0.968400.pt
#   FOLD: 4
#             accuracy =   0.968400       |  0.968400
#             precision =  0.969196  |   recall =    0.968400   |  f1 =    0.968387
#
#
#  ================ 3dmm CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_test_acc_14400_0.998600.pt
#   FOLD: 0
#             accuracy =   0.998600       |  0.998600
#             precision =  0.998600  |   recall =    0.998600   |  f1 =    0.998600
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_test_acc_14400_0.999100.pt
#   FOLD: 1
#             accuracy =   0.999100       |  0.999100
#             precision =  0.999100  |   recall =    0.999100   |  f1 =    0.999100
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_test_acc_11000_0.998600.pt
#   FOLD: 2
#             accuracy =   0.998600       |  0.998600
#             precision =  0.998600  |   recall =    0.998600   |  f1 =    0.998600
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_test_acc_13600_0.998900.pt
#   FOLD: 3
#             accuracy =   0.998900       |  0.998900
#             precision =  0.998900  |   recall =    0.998900   |  f1 =    0.998900
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_test_acc_14400_0.999000.pt
#   FOLD: 4
#             accuracy =   0.999000       |  0.999000
#             precision =  0.999000  |   recall =    0.999000   |  f1 =    0.999000
#
#
#  ================ faceswap_2d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_test_acc_13400_0.802500.pt
#   FOLD: 0
#             accuracy =   0.802500       |  0.802500
#             precision =  0.809033  |   recall =    0.802500   |  f1 =    0.801451
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_test_acc_11000_0.744500.pt
#   FOLD: 1
#             accuracy =   0.744500       |  0.744500
#             precision =  0.761907  |   recall =    0.744500   |  f1 =    0.740183
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_test_acc_11000_0.748500.pt
#   FOLD: 2
#             accuracy =   0.748500       |  0.748500
#             precision =  0.769281  |   recall =    0.748500   |  f1 =    0.743552
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_test_acc_14000_0.756600.pt
#   FOLD: 3
#             accuracy =   0.756600       |  0.756600
#             precision =  0.756613  |   recall =    0.756600   |  f1 =    0.756597
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_test_acc_14600_0.777400.pt
#   FOLD: 4
#             accuracy =   0.777400       |  0.777400
#             precision =  0.777400  |   recall =    0.777400   |  f1 =    0.777400
#
#
#  ================ faceswap_3d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.0264_0.5584_0.8305)_fold_0/step/bestcapsule_test_acc_13000_0.830500.pt
#   FOLD: 0
#             accuracy =   0.830500       |  0.830500
#             precision =  0.832194  |   recall =    0.830500   |  f1 =    0.830284
# Test image dataset:  10000
#             pt file:  (2.0324_0.5335_0.7618)_fold_1/step/bestcapsule_test_acc_14400_0.761800.pt
#   FOLD: 1
#             accuracy =   0.761800       |  0.761800
#             precision =  0.785122  |   recall =    0.761800   |  f1 =    0.756827
# Test image dataset:  10000
#             pt file:  (2.0435_0.5569_0.7759)_fold_2/step/bestcapsule_test_acc_9800_0.775900.pt
#   FOLD: 2
#             accuracy =   0.775900       |  0.775900
#             precision =  0.790284  |   recall =    0.775900   |  f1 =    0.773089
# Test image dataset:  10000
#             pt file:  (2.0353_0.5974_0.7937)_fold_3/step/bestcapsule_test_acc_10600_0.793700.pt
#   FOLD: 3
#             accuracy =   0.793700       |  0.793700
#             precision =  0.808046  |   recall =    0.793700   |  f1 =    0.791270
# Test image dataset:  10000
#             pt file:  (2.0289_0.6418_0.8168)_fold_4/step/bestcapsule_test_acc_10600_0.816800.pt
#   FOLD: 4
#             accuracy =   0.816800       |  0.816800
#             precision =  0.818739  |   recall =    0.816800   |  f1 =    0.816521
#
#
#  ================ monkey CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.3278_0.6050_0.7027)_fold_0/step/bestcapsule_test_acc_11800_0.702700.pt
#   FOLD: 0
#             accuracy =   0.702700       |  0.702700
#             precision =  0.705855  |   recall =    0.702700   |  f1 =    0.701556
# Test image dataset:  10000
#             pt file:  (2.3582_0.6788_0.7067)_fold_1/step/bestcapsule_test_acc_13200_0.706700.pt
#   FOLD: 1
#             accuracy =   0.706700       |  0.706700
#             precision =  0.710377  |   recall =    0.706700   |  f1 =    0.705413
# Test image dataset:  10000
#             pt file:  (2.3958_0.5939_0.6712)_fold_2/step/bestcapsule_test_acc_14800_0.671200.pt
#   FOLD: 2
#             accuracy =   0.671200       |  0.671200
#             precision =  0.671225  |   recall =    0.671200   |  f1 =    0.671188
# Test image dataset:  10000
#             pt file:  (2.3718_0.6529_0.6899)_fold_3/step/bestcapsule_test_acc_11400_0.689900.pt
#   FOLD: 3
#             accuracy =   0.689900       |  0.689900
#             precision =  0.691269  |   recall =    0.689900   |  f1 =    0.689344
# Test image dataset:  10000
#             pt file:  (2.3423_0.5859_0.6855)_fold_4/step/bestcapsule_test_acc_13000_0.685500.pt
#   FOLD: 4
#             accuracy =   0.685500       |  0.685500
#             precision =  0.686954  |   recall =    0.685500   |  f1 =    0.684887
#
#
#  ================ reenact CHECKPOINT ================
# Test image dataset:  9566
#             pt file:  (1.9550_0.9998_0.9999)_fold_0/step/bestcapsule_test_acc_10200_0.999895.pt
#   FOLD: 0
#             accuracy =   0.999895       |  0.999895
#             precision =  0.999891  |   recall =    0.999900   |  f1 =    0.999895
# Test image dataset:  9566
#             pt file:  (1.9554_0.9995_0.9999)_fold_1/step/bestcapsule_test_acc_7000_0.999895.pt
#   FOLD: 1
#             accuracy =   0.999895       |  0.999895
#             precision =  0.999891  |   recall =    0.999900   |  f1 =    0.999895
# Test image dataset:  9566
#             pt file:  (1.9559_0.9997_0.9999)_fold_2/step/bestcapsule_test_acc_9200_0.999895.pt
#   FOLD: 2
#             accuracy =   0.999895       |  0.999895
#             precision =  0.999891  |   recall =    0.999900   |  f1 =    0.999895
# Test image dataset:  9566
#             pt file:  (1.9559_0.9997_0.9999)_fold_3/step/bestcapsule_test_acc_1600_0.999895.pt
#   FOLD: 3
#             accuracy =   0.999895       |  0.999895
#             precision =  0.999891  |   recall =    0.999900   |  f1 =    0.999895
# Test image dataset:  9566
#             pt file:  (1.9557_0.9998_0.9999)_fold_4/step/bestcapsule_test_acc_6200_0.999895.pt
#   FOLD: 4
#             accuracy =   0.999895       |  0.999895
#             precision =  0.999891  |   recall =    0.999900   |  f1 =    0.999895
#
#
#  ================ stargan CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9646_0.9949_0.9949)_fold_0/step/bestcapsule_test_acc_12600_0.994900.pt
#   FOLD: 0
#             accuracy =   0.994900       |  0.994900
#             precision =  0.994917  |   recall =    0.994900   |  f1 =    0.994900
# Test image dataset:  10000
#             pt file:  (1.9669_0.9911_0.9923)_fold_1/step/bestcapsule_test_acc_14600_0.992300.pt
#   FOLD: 1
#             accuracy =   0.992300       |  0.992300
#             precision =  0.992344  |   recall =    0.992300   |  f1 =    0.992300
# Test image dataset:  10000
#             pt file:  (1.9683_0.9892_0.9923)_fold_2/step/bestcapsule_test_acc_14400_0.992300.pt
#   FOLD: 2
#             accuracy =   0.992300       |  0.992300
#             precision =  0.992301  |   recall =    0.992300   |  f1 =    0.992300
# Test image dataset:  10000
#             pt file:  (1.9713_0.9897_0.9897)_fold_3/step/bestcapsule_test_acc_13200_0.989700.pt
#   FOLD: 3
#             accuracy =   0.989700       |  0.989700
#             precision =  0.989700  |   recall =    0.989700   |  f1 =    0.989700
# Test image dataset:  10000
#             pt file:  (1.9639_0.9912_0.9945)_fold_4/step/bestcapsule_test_acc_6400_0.994500.pt
#   FOLD: 4
#             accuracy =   0.994500       |  0.994500
#             precision =  0.994510  |   recall =    0.994500   |  f1 =    0.994500
#
#
#  ================ x2face CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_test_acc_9400_0.985200.pt
#   FOLD: 0
#             accuracy =   0.985200       |  0.985200
#             precision =  0.985228  |   recall =    0.985200   |  f1 =    0.985200
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_test_acc_14600_0.985900.pt
#   FOLD: 1
#             accuracy =   0.985900       |  0.985900
#             precision =  0.985959  |   recall =    0.985900   |  f1 =    0.985900
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_test_acc_14400_0.983100.pt
#   FOLD: 2
#             accuracy =   0.983100       |  0.983100
#             precision =  0.983260  |   recall =    0.983100   |  f1 =    0.983099
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_test_acc_11200_0.983500.pt
#   FOLD: 3
#             accuracy =   0.983500       |  0.983500
#             precision =  0.983533  |   recall =    0.983500   |  f1 =    0.983500
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_test_acc_11200_0.982900.pt
#   FOLD: 4
#             accuracy =   0.982900       |  0.982900
#             precision =  0.982924  |   recall =    0.982900   |  f1 =    0.982900
#
# *********************************************************
#              BRIGHTNESS:  0.5
#
#
#  ================ deepfake CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_test_acc_3000_0.942100.pt
#   FOLD: 0
#             accuracy =   0.573100       |  0.573100
#             precision =  0.739323  |   recall =    0.573100   |  f1 =    0.483398
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_test_acc_11600_0.981000.pt
#   FOLD: 1
#             accuracy =   0.583000       |  0.583000
#             precision =  0.770261  |   recall =    0.583000   |  f1 =    0.495632
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_test_acc_15000_0.955700.pt
#   FOLD: 2
#             accuracy =   0.632000       |  0.632000
#             precision =  0.786914  |   recall =    0.632000   |  f1 =    0.574575
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_test_acc_7000_0.969000.pt
#   FOLD: 3
#             accuracy =   0.687300       |  0.687300
#             precision =  0.800049  |   recall =    0.687300   |  f1 =    0.654879
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_test_acc_9200_0.968400.pt
#   FOLD: 4
#             accuracy =   0.543700       |  0.543700
#             precision =  0.761424  |   recall =    0.543700   |  f1 =    0.423711
#
#
#  ================ 3dmm CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_test_acc_14400_0.998600.pt
#   FOLD: 0
#             accuracy =   0.991700       |  0.991700
#             precision =  0.991712  |   recall =    0.991700   |  f1 =    0.991700
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_test_acc_14400_0.999100.pt
#   FOLD: 1
#             accuracy =   0.991600       |  0.991600
#             precision =  0.991610  |   recall =    0.991600   |  f1 =    0.991600
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_test_acc_11000_0.998600.pt
#   FOLD: 2
#             accuracy =   0.985200       |  0.985200
#             precision =  0.985200  |   recall =    0.985200   |  f1 =    0.985200
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_test_acc_13600_0.998900.pt
#   FOLD: 3
#             accuracy =   0.967700       |  0.967700
#             precision =  0.969268  |   recall =    0.967700   |  f1 =    0.967673
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_test_acc_14400_0.999000.pt
#   FOLD: 4
#             accuracy =   0.990300       |  0.990300
#             precision =  0.990300  |   recall =    0.990300   |  f1 =    0.990300
#
#
#  ================ faceswap_2d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_test_acc_13400_0.802500.pt
#   FOLD: 0
#             accuracy =   0.503200       |  0.503200
#             precision =  0.589696  |   recall =    0.503200   |  f1 =    0.345385
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_test_acc_11000_0.744500.pt
#   FOLD: 1
#             accuracy =   0.522700       |  0.522700
#             precision =  0.585044  |   recall =    0.522700   |  f1 =    0.415597
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_test_acc_11000_0.748500.pt
#   FOLD: 2
#             accuracy =   0.524600       |  0.524600
#             precision =  0.615176  |   recall =    0.524600   |  f1 =    0.408262
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_test_acc_14000_0.756600.pt
#   FOLD: 3
#             accuracy =   0.573200       |  0.573200
#             precision =  0.593020  |   recall =    0.573200   |  f1 =    0.549186
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_test_acc_14600_0.777400.pt
#   FOLD: 4
#             accuracy =   0.499900       |  0.499900
#             precision =  0.449975  |   recall =    0.499900   |  f1 =    0.333644
#
#
#  ================ faceswap_3d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.0264_0.5584_0.8305)_fold_0/step/bestcapsule_test_acc_13000_0.830500.pt
#   FOLD: 0
#             accuracy =   0.563900       |  0.563900
#             precision =  0.586150  |   recall =    0.563900   |  f1 =    0.533799
# Test image dataset:  10000
#             pt file:  (2.0324_0.5335_0.7618)_fold_1/step/bestcapsule_test_acc_14400_0.761800.pt
#   FOLD: 1
#             accuracy =   0.549800       |  0.549800
#             precision =  0.569010  |   recall =    0.549800   |  f1 =    0.516127
# Test image dataset:  10000
#             pt file:  (2.0435_0.5569_0.7759)_fold_2/step/bestcapsule_test_acc_9800_0.775900.pt
#   FOLD: 2
#             accuracy =   0.579900       |  0.579900
#             precision =  0.589731  |   recall =    0.579900   |  f1 =    0.568069
# Test image dataset:  10000
#             pt file:  (2.0353_0.5974_0.7937)_fold_3/step/bestcapsule_test_acc_10600_0.793700.pt
#   FOLD: 3
#             accuracy =   0.524800       |  0.524800
#             precision =  0.574953  |   recall =    0.524800   |  f1 =    0.429339
# Test image dataset:  10000
#             pt file:  (2.0289_0.6418_0.8168)_fold_4/step/bestcapsule_test_acc_10600_0.816800.pt
#   FOLD: 4
#             accuracy =   0.499200       |  0.499200
#             precision =  0.465316  |   recall =    0.499200   |  f1 =    0.337361
#
#
#  ================ monkey CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.3278_0.6050_0.7027)_fold_0/step/bestcapsule_test_acc_11800_0.702700.pt
#   FOLD: 0
#             accuracy =   0.505600       |  0.505600
#             precision =  0.685621  |   recall =    0.505600   |  f1 =    0.347363
# Test image dataset:  10000
#             pt file:  (2.3582_0.6788_0.7067)_fold_1/step/bestcapsule_test_acc_13200_0.706700.pt
#   FOLD: 1
#             accuracy =   0.588500       |  0.588500
#             precision =  0.640564  |   recall =    0.588500   |  f1 =    0.546507
# Test image dataset:  10000
#             pt file:  (2.3958_0.5939_0.6712)_fold_2/step/bestcapsule_test_acc_14800_0.671200.pt
#   FOLD: 2
#             accuracy =   0.502200       |  0.502200
#             precision =  0.547970  |   recall =    0.502200   |  f1 =    0.346261
# Test image dataset:  10000
#             pt file:  (2.3718_0.6529_0.6899)_fold_3/step/bestcapsule_test_acc_11400_0.689900.pt
#   FOLD: 3
#             accuracy =   0.535000       |  0.535000
#             precision =  0.636577  |   recall =    0.535000   |  f1 =    0.428794
# Test image dataset:  10000
#             pt file:  (2.3423_0.5859_0.6855)_fold_4/step/bestcapsule_test_acc_13000_0.685500.pt
#   FOLD: 4
#             accuracy =   0.555500       |  0.555500
#             precision =  0.556254  |   recall =    0.555500   |  f1 =    0.554005
#
#
#  ================ reenact CHECKPOINT ================
# Test image dataset:  9566
#             pt file:  (1.9550_0.9998_0.9999)_fold_0/step/bestcapsule_test_acc_10200_0.999895.pt
#   FOLD: 0
#             accuracy =   0.523207       |  0.523098
#             precision =  0.625122  |   recall =    0.500576   |  f1 =    0.345066
# Test image dataset:  9566
#             pt file:  (1.9554_0.9995_0.9999)_fold_1/step/bestcapsule_test_acc_7000_0.999895.pt
#   FOLD: 1
#             accuracy =   0.529584       |  0.529473
#             precision =  0.742333  |   recall =    0.507256   |  f1 =    0.359640
# Test image dataset:  9566
#             pt file:  (1.9559_0.9997_0.9999)_fold_2/step/bestcapsule_test_acc_9200_0.999895.pt
#   FOLD: 2
#             accuracy =   0.521848       |  0.521739
#             precision =  0.311145  |   recall =    0.499210   |  f1 =    0.343101
# Test image dataset:  9566
#             pt file:  (1.9559_0.9997_0.9999)_fold_3/step/bestcapsule_test_acc_1600_0.999895.pt
#   FOLD: 3
#             accuracy =   0.520803       |  0.520694
#             precision =  0.260892  |   recall =    0.498200   |  f1 =    0.342453
# Test image dataset:  9566
#             pt file:  (1.9557_0.9998_0.9999)_fold_4/step/bestcapsule_test_acc_6200_0.999895.pt
#   FOLD: 4
#             accuracy =   0.522789       |  0.522680
#             precision =  0.761370  |   recall =    0.500110   |  f1 =    0.343508
#
#
#  ================ stargan CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9646_0.9949_0.9949)_fold_0/step/bestcapsule_test_acc_12600_0.994900.pt
#   FOLD: 0
#             accuracy =   0.495200       |  0.495200
#             precision =  0.491374  |   recall =    0.495200   |  f1 =    0.432242
# Test image dataset:  10000
#             pt file:  (1.9669_0.9911_0.9923)_fold_1/step/bestcapsule_test_acc_14600_0.992300.pt
#   FOLD: 1
#             accuracy =   0.524200       |  0.524200
#             precision =  0.539795  |   recall =    0.524200   |  f1 =    0.472524
# Test image dataset:  10000
#             pt file:  (1.9683_0.9892_0.9923)_fold_2/step/bestcapsule_test_acc_14400_0.992300.pt
#   FOLD: 2
#             accuracy =   0.527200       |  0.527200
#             precision =  0.563753  |   recall =    0.527200   |  f1 =    0.448090
# Test image dataset:  10000
#             pt file:  (1.9713_0.9897_0.9897)_fold_3/step/bestcapsule_test_acc_13200_0.989700.pt
#   FOLD: 3
#             accuracy =   0.498400       |  0.498400
#             precision =  0.496245  |   recall =    0.498400   |  f1 =    0.414368
# Test image dataset:  10000
#             pt file:  (1.9639_0.9912_0.9945)_fold_4/step/bestcapsule_test_acc_6400_0.994500.pt
#   FOLD: 4
#             accuracy =   0.514300       |  0.514300
#             precision =  0.560651  |   recall =    0.514300   |  f1 =    0.399587
#
#
#  ================ x2face CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_test_acc_9400_0.985200.pt
#   FOLD: 0
#             accuracy =   0.524900       |  0.524900
#             precision =  0.756384  |   recall =    0.524900   |  f1 =    0.386398
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_test_acc_14600_0.985900.pt
#   FOLD: 1
#             accuracy =   0.658900       |  0.658900
#             precision =  0.796022  |   recall =    0.658900   |  f1 =    0.614226
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_test_acc_14400_0.983100.pt
#   FOLD: 2
#             accuracy =   0.540000       |  0.540000
#             precision =  0.760417  |   recall =    0.540000   |  f1 =    0.416540
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_test_acc_11200_0.983500.pt
#   FOLD: 3
#             accuracy =   0.630500       |  0.630500
#             precision =  0.786033  |   recall =    0.630500   |  f1 =    0.572368
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_test_acc_11200_0.982900.pt
#   FOLD: 4
#             accuracy =   0.511700       |  0.511700
#             precision =  0.752960  |   recall =    0.511700   |  f1 =    0.358819
#
# *********************************************************
#              BRIGHTNESS:  0.75
#
#
#  ================ deepfake CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_test_acc_3000_0.942100.pt
#   FOLD: 0
#             accuracy =   0.902700       |  0.902700
#             precision =  0.916971  |   recall =    0.902700   |  f1 =    0.901860
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_test_acc_11600_0.981000.pt
#   FOLD: 1
#             accuracy =   0.922800       |  0.922800
#             precision =  0.932692  |   recall =    0.922800   |  f1 =    0.922356
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_test_acc_15000_0.955700.pt
#   FOLD: 2
#             accuracy =   0.931100       |  0.931100
#             precision =  0.939151  |   recall =    0.931100   |  f1 =    0.930783
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_test_acc_7000_0.969000.pt
#   FOLD: 3
#             accuracy =   0.951700       |  0.951700
#             precision =  0.954833  |   recall =    0.951700   |  f1 =    0.951617
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_test_acc_9200_0.968400.pt
#   FOLD: 4
#             accuracy =   0.944000       |  0.944000
#             precision =  0.949600  |   recall =    0.944000   |  f1 =    0.943825
#
#
#  ================ 3dmm CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_test_acc_14400_0.998600.pt
#   FOLD: 0
#             accuracy =   0.996400       |  0.996400
#             precision =  0.996403  |   recall =    0.996400   |  f1 =    0.996400
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_test_acc_14400_0.999100.pt
#   FOLD: 1
#             accuracy =   0.996800       |  0.996800
#             precision =  0.996803  |   recall =    0.996800   |  f1 =    0.996800
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_test_acc_11000_0.998600.pt
#   FOLD: 2
#             accuracy =   0.995800       |  0.995800
#             precision =  0.995829  |   recall =    0.995800   |  f1 =    0.995800
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_test_acc_13600_0.998900.pt
#   FOLD: 3
#             accuracy =   0.995200       |  0.995200
#             precision =  0.995208  |   recall =    0.995200   |  f1 =    0.995200
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_test_acc_14400_0.999000.pt
#   FOLD: 4
#             accuracy =   0.997200       |  0.997200
#             precision =  0.997203  |   recall =    0.997200   |  f1 =    0.997200
#
#
#  ================ faceswap_2d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_test_acc_13400_0.802500.pt
#   FOLD: 0
#             accuracy =   0.610000       |  0.610000
#             precision =  0.719314  |   recall =    0.610000   |  f1 =    0.554485
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_test_acc_11000_0.744500.pt
#   FOLD: 1
#             accuracy =   0.629000       |  0.629000
#             precision =  0.664083  |   recall =    0.629000   |  f1 =    0.608049
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_test_acc_11000_0.748500.pt
#   FOLD: 2
#             accuracy =   0.586600       |  0.586600
#             precision =  0.681779  |   recall =    0.586600   |  f1 =    0.524336
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_test_acc_14000_0.756600.pt
#   FOLD: 3
#             accuracy =   0.628100       |  0.628100
#             precision =  0.636979  |   recall =    0.628100   |  f1 =    0.621974
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_test_acc_14600_0.777400.pt
#   FOLD: 4
#             accuracy =   0.549500       |  0.549500
#             precision =  0.713756  |   recall =    0.549500   |  f1 =    0.442377
#
#
#  ================ faceswap_3d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.0264_0.5584_0.8305)_fold_0/step/bestcapsule_test_acc_13000_0.830500.pt
#   FOLD: 0
#             accuracy =   0.664000       |  0.664000
#             precision =  0.669193  |   recall =    0.664000   |  f1 =    0.661402
# Test image dataset:  10000
#             pt file:  (2.0324_0.5335_0.7618)_fold_1/step/bestcapsule_test_acc_14400_0.761800.pt
#   FOLD: 1
#             accuracy =   0.615500       |  0.615500
#             precision =  0.628954  |   recall =    0.615500   |  f1 =    0.605203
# Test image dataset:  10000
#             pt file:  (2.0435_0.5569_0.7759)_fold_2/step/bestcapsule_test_acc_9800_0.775900.pt
#   FOLD: 2
#             accuracy =   0.637100       |  0.637100
#             precision =  0.639165  |   recall =    0.637100   |  f1 =    0.635749
# Test image dataset:  10000
#             pt file:  (2.0353_0.5974_0.7937)_fold_3/step/bestcapsule_test_acc_10600_0.793700.pt
#   FOLD: 3
#             accuracy =   0.626300       |  0.626300
#             precision =  0.652885  |   recall =    0.626300   |  f1 =    0.609316
# Test image dataset:  10000
#             pt file:  (2.0289_0.6418_0.8168)_fold_4/step/bestcapsule_test_acc_10600_0.816800.pt
#   FOLD: 4
#             accuracy =   0.595600       |  0.595600
#             precision =  0.647075  |   recall =    0.595600   |  f1 =    0.556823
#
#
#  ================ monkey CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.3278_0.6050_0.7027)_fold_0/step/bestcapsule_test_acc_11800_0.702700.pt
#   FOLD: 0
#             accuracy =   0.626500       |  0.626500
#             precision =  0.661322  |   recall =    0.626500   |  f1 =    0.605195
# Test image dataset:  10000
#             pt file:  (2.3582_0.6788_0.7067)_fold_1/step/bestcapsule_test_acc_13200_0.706700.pt
#   FOLD: 1
#             accuracy =   0.652600       |  0.652600
#             precision =  0.679383  |   recall =    0.652600   |  f1 =    0.639130
# Test image dataset:  10000
#             pt file:  (2.3958_0.5939_0.6712)_fold_2/step/bestcapsule_test_acc_14800_0.671200.pt
#   FOLD: 2
#             accuracy =   0.571200       |  0.571200
#             precision =  0.666175  |   recall =    0.571200   |  f1 =    0.499718
# Test image dataset:  10000
#             pt file:  (2.3718_0.6529_0.6899)_fold_3/step/bestcapsule_test_acc_11400_0.689900.pt
#   FOLD: 3
#             accuracy =   0.587100       |  0.587100
#             precision =  0.678201  |   recall =    0.587100   |  f1 =    0.526596
# Test image dataset:  10000
#             pt file:  (2.3423_0.5859_0.6855)_fold_4/step/bestcapsule_test_acc_13000_0.685500.pt
#   FOLD: 4
#             accuracy =   0.612000       |  0.612000
#             precision =  0.612714  |   recall =    0.612000   |  f1 =    0.611384
#
#
#  ================ reenact CHECKPOINT ================
# Test image dataset:  9566
#             pt file:  (1.9550_0.9998_0.9999)_fold_0/step/bestcapsule_test_acc_10200_0.999895.pt
#   FOLD: 0
#             accuracy =   0.835668       |  0.835643
#             precision =  0.879768  |   recall =    0.827906   |  f1 =    0.828188
# Test image dataset:  9566
#             pt file:  (1.9554_0.9995_0.9999)_fold_1/step/bestcapsule_test_acc_7000_0.999895.pt
#   FOLD: 1
#             accuracy =   0.807025       |  0.807005
#             precision =  0.864728  |   recall =    0.797882   |  f1 =    0.795467
# Test image dataset:  9566
#             pt file:  (1.9559_0.9997_0.9999)_fold_2/step/bestcapsule_test_acc_9200_0.999895.pt
#   FOLD: 2
#             accuracy =   0.761133       |  0.761108
#             precision =  0.842977  |   recall =    0.749790   |  f1 =    0.740173
# Test image dataset:  9566
#             pt file:  (1.9559_0.9997_0.9999)_fold_3/step/bestcapsule_test_acc_1600_0.999895.pt
#   FOLD: 3
#             accuracy =   0.863266       |  0.863220
#             precision =  0.894533  |   recall =    0.856929   |  f1 =    0.858763
# Test image dataset:  9566
#             pt file:  (1.9557_0.9998_0.9999)_fold_4/step/bestcapsule_test_acc_6200_0.999895.pt
#   FOLD: 4
#             accuracy =   0.798766       |  0.798749
#             precision =  0.860697  |   recall =    0.789222   |  f1 =    0.785783
#
#
#  ================ stargan CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9646_0.9949_0.9949)_fold_0/step/bestcapsule_test_acc_12600_0.994900.pt
#   FOLD: 0
#             accuracy =   0.740700       |  0.740700
#             precision =  0.746165  |   recall =    0.740700   |  f1 =    0.739253
# Test image dataset:  10000
#             pt file:  (1.9669_0.9911_0.9923)_fold_1/step/bestcapsule_test_acc_14600_0.992300.pt
#   FOLD: 1
#             accuracy =   0.759000       |  0.759000
#             precision =  0.761832  |   recall =    0.759000   |  f1 =    0.758347
# Test image dataset:  10000
#             pt file:  (1.9683_0.9892_0.9923)_fold_2/step/bestcapsule_test_acc_14400_0.992300.pt
#   FOLD: 2
#             accuracy =   0.739800       |  0.739800
#             precision =  0.767540  |   recall =    0.739800   |  f1 =    0.732876
# Test image dataset:  10000
#             pt file:  (1.9713_0.9897_0.9897)_fold_3/step/bestcapsule_test_acc_13200_0.989700.pt
#   FOLD: 3
#             accuracy =   0.734800       |  0.734800
#             precision =  0.760628  |   recall =    0.734800   |  f1 =    0.728063
# Test image dataset:  10000
#             pt file:  (1.9639_0.9912_0.9945)_fold_4/step/bestcapsule_test_acc_6400_0.994500.pt
#   FOLD: 4
#             accuracy =   0.642100       |  0.642100
#             precision =  0.714963  |   recall =    0.642100   |  f1 =    0.608964
#
#
#  ================ x2face CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_test_acc_9400_0.985200.pt
#   FOLD: 0
#             accuracy =   0.889800       |  0.889800
#             precision =  0.908951  |   recall =    0.889800   |  f1 =    0.888495
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_test_acc_14600_0.985900.pt
#   FOLD: 1
#             accuracy =   0.943900       |  0.943900
#             precision =  0.949317  |   recall =    0.943900   |  f1 =    0.943730
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_test_acc_14400_0.983100.pt
#   FOLD: 2
#             accuracy =   0.913400       |  0.913400
#             precision =  0.925703  |   recall =    0.913400   |  f1 =    0.912770
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_test_acc_11200_0.983500.pt
#   FOLD: 3
#             accuracy =   0.907700       |  0.907700
#             precision =  0.921009  |   recall =    0.907700   |  f1 =    0.906965
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_test_acc_11200_0.982900.pt
#   FOLD: 4
#             accuracy =   0.882400       |  0.882400
#             precision =  0.903369  |   recall =    0.882400   |  f1 =    0.880852
#
# *********************************************************
#              BRIGHTNESS:  1.5
#
#
#  ================ deepfake CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_test_acc_3000_0.942100.pt
#   FOLD: 0
#             accuracy =   0.770300       |  0.770300
#             precision =  0.840556  |   recall =    0.770300   |  f1 =    0.757809
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_test_acc_11600_0.981000.pt
#   FOLD: 1
#             accuracy =   0.850500       |  0.850500
#             precision =  0.881015  |   recall =    0.850500   |  f1 =    0.847446
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_test_acc_15000_0.955700.pt
#   FOLD: 2
#             accuracy =   0.854000       |  0.854000
#             precision =  0.883282  |   recall =    0.854000   |  f1 =    0.851157
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_test_acc_7000_0.969000.pt
#   FOLD: 3
#             accuracy =   0.871400       |  0.871400
#             precision =  0.895991  |   recall =    0.871400   |  f1 =    0.869372
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_test_acc_9200_0.968400.pt
#   FOLD: 4
#             accuracy =   0.735200       |  0.735200
#             precision =  0.824788  |   recall =    0.735200   |  f1 =    0.715587
#
#
#  ================ 3dmm CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_test_acc_14400_0.998600.pt
#   FOLD: 0
#             accuracy =   0.993100       |  0.993100
#             precision =  0.993136  |   recall =    0.993100   |  f1 =    0.993100
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_test_acc_14400_0.999100.pt
#   FOLD: 1
#             accuracy =   0.996900       |  0.996900
#             precision =  0.996900  |   recall =    0.996900   |  f1 =    0.996900
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_test_acc_11000_0.998600.pt
#   FOLD: 2
#             accuracy =   0.993200       |  0.993200
#             precision =  0.993258  |   recall =    0.993200   |  f1 =    0.993200
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_test_acc_13600_0.998900.pt
#   FOLD: 3
#             accuracy =   0.996100       |  0.996100
#             precision =  0.996104  |   recall =    0.996100   |  f1 =    0.996100
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_test_acc_14400_0.999000.pt
#   FOLD: 4
#             accuracy =   0.992000       |  0.992000
#             precision =  0.992026  |   recall =    0.992000   |  f1 =    0.992000
#
#
#  ================ faceswap_2d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_test_acc_13400_0.802500.pt
#   FOLD: 0
#             accuracy =   0.622700       |  0.622700
#             precision =  0.711046  |   recall =    0.622700   |  f1 =    0.578599
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_test_acc_11000_0.744500.pt
#   FOLD: 1
#             accuracy =   0.645900       |  0.645900
#             precision =  0.667707  |   recall =    0.645900   |  f1 =    0.634002
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_test_acc_11000_0.748500.pt
#   FOLD: 2
#             accuracy =   0.645500       |  0.645500
#             precision =  0.676484  |   recall =    0.645500   |  f1 =    0.629227
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_test_acc_14000_0.756600.pt
#   FOLD: 3
#             accuracy =   0.655700       |  0.655700
#             precision =  0.658786  |   recall =    0.655700   |  f1 =    0.654019
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_test_acc_14600_0.777400.pt
#   FOLD: 4
#             accuracy =   0.644000       |  0.644000
#             precision =  0.683945  |   recall =    0.644000   |  f1 =    0.623564
#
#
#  ================ faceswap_3d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.0264_0.5584_0.8305)_fold_0/step/bestcapsule_test_acc_13000_0.830500.pt
#   FOLD: 0
#             accuracy =   0.697900       |  0.697900
#             precision =  0.712367  |   recall =    0.697900   |  f1 =    0.692666
# Test image dataset:  10000
#             pt file:  (2.0324_0.5335_0.7618)_fold_1/step/bestcapsule_test_acc_14400_0.761800.pt
#   FOLD: 1
#             accuracy =   0.618600       |  0.618600
#             precision =  0.644238  |   recall =    0.618600   |  f1 =    0.600864
# Test image dataset:  10000
#             pt file:  (2.0435_0.5569_0.7759)_fold_2/step/bestcapsule_test_acc_9800_0.775900.pt
#   FOLD: 2
#             accuracy =   0.604200       |  0.604200
#             precision =  0.622399  |   recall =    0.604200   |  f1 =    0.588919
# Test image dataset:  10000
#             pt file:  (2.0353_0.5974_0.7937)_fold_3/step/bestcapsule_test_acc_10600_0.793700.pt
#   FOLD: 3
#             accuracy =   0.599800       |  0.599800
#             precision =  0.651240  |   recall =    0.599800   |  f1 =    0.562608
# Test image dataset:  10000
#             pt file:  (2.0289_0.6418_0.8168)_fold_4/step/bestcapsule_test_acc_10600_0.816800.pt
#   FOLD: 4
#             accuracy =   0.667800       |  0.667800
#             precision =  0.695292  |   recall =    0.667800   |  f1 =    0.655682
#
#
#  ================ monkey CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.3278_0.6050_0.7027)_fold_0/step/bestcapsule_test_acc_11800_0.702700.pt
#   FOLD: 0
#             accuracy =   0.539400       |  0.539400
#             precision =  0.683252  |   recall =    0.539400   |  f1 =    0.426937
# Test image dataset:  10000
#             pt file:  (2.3582_0.6788_0.7067)_fold_1/step/bestcapsule_test_acc_13200_0.706700.pt
#   FOLD: 1
#             accuracy =   0.528800       |  0.528800
#             precision =  0.709713  |   recall =    0.528800   |  f1 =    0.399234
# Test image dataset:  10000
#             pt file:  (2.3958_0.5939_0.6712)_fold_2/step/bestcapsule_test_acc_14800_0.671200.pt
#   FOLD: 2
#             accuracy =   0.568600       |  0.568600
#             precision =  0.698356  |   recall =    0.568600   |  f1 =    0.484255
# Test image dataset:  10000
#             pt file:  (2.3718_0.6529_0.6899)_fold_3/step/bestcapsule_test_acc_11400_0.689900.pt
#   FOLD: 3
#             accuracy =   0.561400       |  0.561400
#             precision =  0.641903  |   recall =    0.561400   |  f1 =    0.488914
# Test image dataset:  10000
#             pt file:  (2.3423_0.5859_0.6855)_fold_4/step/bestcapsule_test_acc_13000_0.685500.pt
#   FOLD: 4
#             accuracy =   0.583000       |  0.583000
#             precision =  0.670511  |   recall =    0.583000   |  f1 =    0.521620
#
#
#  ================ reenact CHECKPOINT ================
# Test image dataset:  9566
#             pt file:  (1.9550_0.9998_0.9999)_fold_0/step/bestcapsule_test_acc_10200_0.999895.pt
#   FOLD: 0
#             accuracy =   0.523312       |  0.523202
#             precision =  0.761506  |   recall =    0.500657   |  f1 =    0.344719
# Test image dataset:  9566
#             pt file:  (1.9554_0.9995_0.9999)_fold_1/step/bestcapsule_test_acc_7000_0.999895.pt
#   FOLD: 1
#             accuracy =   0.523625       |  0.523516
#             precision =  0.761588  |   recall =    0.500986   |  f1 =    0.345445
# Test image dataset:  9566
#             pt file:  (1.9559_0.9997_0.9999)_fold_2/step/bestcapsule_test_acc_9200_0.999895.pt
#   FOLD: 2
#             accuracy =   0.553418       |  0.553347
#             precision =  0.767944  |   recall =    0.532204   |  f1 =    0.410990
# Test image dataset:  9566
#             pt file:  (1.9559_0.9997_0.9999)_fold_3/step/bestcapsule_test_acc_1600_0.999895.pt
#   FOLD: 3
#             accuracy =   0.522685       |  0.522575
#             precision =  0.261342  |   recall =    0.500000   |  f1 =    0.343265
# Test image dataset:  9566
#             pt file:  (1.9557_0.9998_0.9999)_fold_4/step/bestcapsule_test_acc_6200_0.999895.pt
#   FOLD: 4
#             accuracy =   0.572444       |  0.572399
#             precision =  0.775028  |   recall =    0.552124   |  f1 =    0.449269
#
#
#  ================ stargan CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9646_0.9949_0.9949)_fold_0/step/bestcapsule_test_acc_12600_0.994900.pt
#   FOLD: 0
#             accuracy =   0.524400       |  0.524400
#             precision =  0.740878  |   recall =    0.524400   |  f1 =    0.386579
# Test image dataset:  10000
#             pt file:  (1.9669_0.9911_0.9923)_fold_1/step/bestcapsule_test_acc_14600_0.992300.pt
#   FOLD: 1
#             accuracy =   0.512700       |  0.512700
#             precision =  0.725249  |   recall =    0.512700   |  f1 =    0.362253
# Test image dataset:  10000
#             pt file:  (1.9683_0.9892_0.9923)_fold_2/step/bestcapsule_test_acc_14400_0.992300.pt
#   FOLD: 2
#             accuracy =   0.548300       |  0.548300
#             precision =  0.753730  |   recall =    0.548300   |  f1 =    0.433669
# Test image dataset:  10000
#             pt file:  (1.9713_0.9897_0.9897)_fold_3/step/bestcapsule_test_acc_13200_0.989700.pt
#   FOLD: 3
#             accuracy =   0.532400       |  0.532400
#             precision =  0.735927  |   recall =    0.532400   |  f1 =    0.403824
# Test image dataset:  10000
#             pt file:  (1.9639_0.9912_0.9945)_fold_4/step/bestcapsule_test_acc_6400_0.994500.pt
#   FOLD: 4
#             accuracy =   0.535600       |  0.535600
#             precision =  0.749782  |   recall =    0.535600   |  f1 =    0.408883
#
#
#  ================ x2face CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_test_acc_9400_0.985200.pt
#   FOLD: 0
#             accuracy =   0.932100       |  0.932100
#             precision =  0.937769  |   recall =    0.932100   |  f1 =    0.931879
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_test_acc_14600_0.985900.pt
#   FOLD: 1
#             accuracy =   0.888300       |  0.888300
#             precision =  0.907563  |   recall =    0.888300   |  f1 =    0.886964
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_test_acc_14400_0.983100.pt
#   FOLD: 2
#             accuracy =   0.922400       |  0.922400
#             precision =  0.930504  |   recall =    0.922400   |  f1 =    0.922033
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_test_acc_11200_0.983500.pt
#   FOLD: 3
#             accuracy =   0.926000       |  0.926000
#             precision =  0.931609  |   recall =    0.926000   |  f1 =    0.925759
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_test_acc_11200_0.982900.pt
#   FOLD: 4
#             accuracy =   0.905700       |  0.905700
#             precision =  0.918821  |   recall =    0.905700   |  f1 =    0.904956
#
# *********************************************************
#              BRIGHTNESS:  2.0
#
#
#  ================ deepfake CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9607_0.9026_0.9421)_fold_0/step/bestcapsule_test_acc_3000_0.942100.pt
#   FOLD: 0
#             accuracy =   0.600400       |  0.600400
#             precision =  0.776435  |   recall =    0.600400   |  f1 =    0.524738
# Test image dataset:  10000
#             pt file:  (1.9594_0.8933_0.9810)_fold_1/step/bestcapsule_test_acc_11600_0.981000.pt
#   FOLD: 1
#             accuracy =   0.700700       |  0.700700
#             precision =  0.797995  |   recall =    0.700700   |  f1 =    0.674098
# Test image dataset:  10000
#             pt file:  (1.9577_0.9029_0.9557)_fold_2/step/bestcapsule_test_acc_15000_0.955700.pt
#   FOLD: 2
#             accuracy =   0.752600       |  0.752600
#             precision =  0.831899  |   recall =    0.752600   |  f1 =    0.736884
# Test image dataset:  10000
#             pt file:  (1.9603_0.8770_0.9690)_fold_3/step/bestcapsule_test_acc_7000_0.969000.pt
#   FOLD: 3
#             accuracy =   0.676500       |  0.676500
#             precision =  0.800385  |   recall =    0.676500   |  f1 =    0.639311
# Test image dataset:  10000
#             pt file:  (1.9594_0.9057_0.9684)_fold_4/step/bestcapsule_test_acc_9200_0.968400.pt
#   FOLD: 4
#             accuracy =   0.605900       |  0.605900
#             precision =  0.768506  |   recall =    0.605900   |  f1 =    0.535589
#
#
#  ================ 3dmm CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9598_0.9983_0.9986)_fold_0/step/bestcapsule_test_acc_14400_0.998600.pt
#   FOLD: 0
#             accuracy =   0.975200       |  0.975200
#             precision =  0.975844  |   recall =    0.975200   |  f1 =    0.975192
# Test image dataset:  10000
#             pt file:  (1.9570_0.9991_0.9991)_fold_1/step/bestcapsule_test_acc_14400_0.999100.pt
#   FOLD: 1
#             accuracy =   0.987800       |  0.987800
#             precision =  0.987801  |   recall =    0.987800   |  f1 =    0.987800
# Test image dataset:  10000
#             pt file:  (1.9574_0.9963_0.9986)_fold_2/step/bestcapsule_test_acc_11000_0.998600.pt
#   FOLD: 2
#             accuracy =   0.979900       |  0.979900
#             precision =  0.980271  |   recall =    0.979900   |  f1 =    0.979896
# Test image dataset:  10000
#             pt file:  (1.9570_0.9989_0.9989)_fold_3/step/bestcapsule_test_acc_13600_0.998900.pt
#   FOLD: 3
#             accuracy =   0.983400       |  0.983400
#             precision =  0.983737  |   recall =    0.983400   |  f1 =    0.983397
# Test image dataset:  10000
#             pt file:  (1.9590_0.9980_0.9990)_fold_4/step/bestcapsule_test_acc_14400_0.999000.pt
#   FOLD: 4
#             accuracy =   0.964500       |  0.964500
#             precision =  0.965889  |   recall =    0.964500   |  f1 =    0.964474
#
#
#  ================ faceswap_2d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.0374_0.5579_0.8025)_fold_0/step/bestcapsule_test_acc_13400_0.802500.pt
#   FOLD: 0
#             accuracy =   0.568800       |  0.568800
#             precision =  0.662645  |   recall =    0.568800   |  f1 =    0.496116
# Test image dataset:  10000
#             pt file:  (2.0420_0.5126_0.7445)_fold_1/step/bestcapsule_test_acc_11000_0.744500.pt
#   FOLD: 1
#             accuracy =   0.586800       |  0.586800
#             precision =  0.600024  |   recall =    0.586800   |  f1 =    0.572676
# Test image dataset:  10000
#             pt file:  (2.0400_0.5385_0.7485)_fold_2/step/bestcapsule_test_acc_11000_0.748500.pt
#   FOLD: 2
#             accuracy =   0.589800       |  0.589800
#             precision =  0.616222  |   recall =    0.589800   |  f1 =    0.565082
# Test image dataset:  10000
#             pt file:  (2.0646_0.5582_0.7566)_fold_3/step/bestcapsule_test_acc_14000_0.756600.pt
#   FOLD: 3
#             accuracy =   0.576800       |  0.576800
#             precision =  0.587917  |   recall =    0.576800   |  f1 =    0.562985
# Test image dataset:  10000
#             pt file:  (2.0409_0.5623_0.7774)_fold_4/step/bestcapsule_test_acc_14600_0.777400.pt
#   FOLD: 4
#             accuracy =   0.588800       |  0.588800
#             precision =  0.598160  |   recall =    0.588800   |  f1 =    0.578758
#
#
#  ================ faceswap_3d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.0264_0.5584_0.8305)_fold_0/step/bestcapsule_test_acc_13000_0.830500.pt
#   FOLD: 0
#             accuracy =   0.594400       |  0.594400
#             precision =  0.616407  |   recall =    0.594400   |  f1 =    0.574279
# Test image dataset:  10000
#             pt file:  (2.0324_0.5335_0.7618)_fold_1/step/bestcapsule_test_acc_14400_0.761800.pt
#   FOLD: 1
#             accuracy =   0.578400       |  0.578400
#             precision =  0.585008  |   recall =    0.578400   |  f1 =    0.570045
# Test image dataset:  10000
#             pt file:  (2.0435_0.5569_0.7759)_fold_2/step/bestcapsule_test_acc_9800_0.775900.pt
#   FOLD: 2
#             accuracy =   0.567800       |  0.567800
#             precision =  0.571368  |   recall =    0.567800   |  f1 =    0.562329
# Test image dataset:  10000
#             pt file:  (2.0353_0.5974_0.7937)_fold_3/step/bestcapsule_test_acc_10600_0.793700.pt
#   FOLD: 3
#             accuracy =   0.514000       |  0.514000
#             precision =  0.541019  |   recall =    0.514000   |  f1 =    0.418191
# Test image dataset:  10000
#             pt file:  (2.0289_0.6418_0.8168)_fold_4/step/bestcapsule_test_acc_10600_0.816800.pt
#   FOLD: 4
#             accuracy =   0.588800       |  0.588800
#             precision =  0.598623  |   recall =    0.588800   |  f1 =    0.578299
#
#
#  ================ monkey CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (2.3278_0.6050_0.7027)_fold_0/step/bestcapsule_test_acc_11800_0.702700.pt
#   FOLD: 0
#             accuracy =   0.518100       |  0.518100
#             precision =  0.624729  |   recall =    0.518100   |  f1 =    0.387113
# Test image dataset:  10000
#             pt file:  (2.3582_0.6788_0.7067)_fold_1/step/bestcapsule_test_acc_13200_0.706700.pt
#   FOLD: 1
#             accuracy =   0.501900       |  0.501900
#             precision =  0.676402  |   recall =    0.501900   |  f1 =    0.338243
# Test image dataset:  10000
#             pt file:  (2.3958_0.5939_0.6712)_fold_2/step/bestcapsule_test_acc_14800_0.671200.pt
#   FOLD: 2
#             accuracy =   0.526700       |  0.526700
#             precision =  0.713554  |   recall =    0.526700   |  f1 =    0.394181
# Test image dataset:  10000
#             pt file:  (2.3718_0.6529_0.6899)_fold_3/step/bestcapsule_test_acc_11400_0.689900.pt
#   FOLD: 3
#             accuracy =   0.531900       |  0.531900
#             precision =  0.580881  |   recall =    0.531900   |  f1 =    0.448386
# Test image dataset:  10000
#             pt file:  (2.3423_0.5859_0.6855)_fold_4/step/bestcapsule_test_acc_13000_0.685500.pt
#   FOLD: 4
#             accuracy =   0.535200       |  0.535200
#             precision =  0.657504  |   recall =    0.535200   |  f1 =    0.423233
#
#
#  ================ reenact CHECKPOINT ================
# Test image dataset:  9566
#             pt file:  (1.9550_0.9998_0.9999)_fold_0/step/bestcapsule_test_acc_10200_0.999895.pt
#   FOLD: 0
#             accuracy =   0.522685       |  0.522575
#             precision =  0.261342  |   recall =    0.500000   |  f1 =    0.343265
# Test image dataset:  9566
#             pt file:  (1.9554_0.9995_0.9999)_fold_1/step/bestcapsule_test_acc_7000_0.999895.pt
#   FOLD: 1
#             accuracy =   0.522685       |  0.522575
#             precision =  0.261342  |   recall =    0.500000   |  f1 =    0.343265
# Test image dataset:  9566
#             pt file:  (1.9559_0.9997_0.9999)_fold_2/step/bestcapsule_test_acc_9200_0.999895.pt
#   FOLD: 2
#             accuracy =   0.522685       |  0.522575
#             precision =  0.261342  |   recall =    0.500000   |  f1 =    0.343265
# Test image dataset:  9566
#             pt file:  (1.9559_0.9997_0.9999)_fold_3/step/bestcapsule_test_acc_1600_0.999895.pt
#   FOLD: 3
#             accuracy =   0.522685       |  0.522575
#             precision =  0.261342  |   recall =    0.500000   |  f1 =    0.343265
# Test image dataset:  9566
#             pt file:  (1.9557_0.9998_0.9999)_fold_4/step/bestcapsule_test_acc_6200_0.999895.pt
#   FOLD: 4
#             accuracy =   0.522685       |  0.522575
#             precision =  0.261342  |   recall =    0.500000   |  f1 =    0.343265
#
#
#  ================ stargan CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9646_0.9949_0.9949)_fold_0/step/bestcapsule_test_acc_12600_0.994900.pt
#   FOLD: 0
#             accuracy =   0.510800       |  0.510800
#             precision =  0.748185  |   recall =    0.510800   |  f1 =    0.357059
# Test image dataset:  10000
#             pt file:  (1.9669_0.9911_0.9923)_fold_1/step/bestcapsule_test_acc_14600_0.992300.pt
#   FOLD: 1
#             accuracy =   0.510900       |  0.510900
#             precision =  0.743907  |   recall =    0.510900   |  f1 =    0.357439
# Test image dataset:  10000
#             pt file:  (1.9683_0.9892_0.9923)_fold_2/step/bestcapsule_test_acc_14400_0.992300.pt
#   FOLD: 2
#             accuracy =   0.504200       |  0.504200
#             precision =  0.719805  |   recall =    0.504200   |  f1 =    0.343117
# Test image dataset:  10000
#             pt file:  (1.9713_0.9897_0.9897)_fold_3/step/bestcapsule_test_acc_13200_0.989700.pt
#   FOLD: 3
#             accuracy =   0.504600       |  0.504600
#             precision =  0.722310  |   recall =    0.504600   |  f1 =    0.343991
# Test image dataset:  10000
#             pt file:  (1.9639_0.9912_0.9945)_fold_4/step/bestcapsule_test_acc_6400_0.994500.pt
#   FOLD: 4
#             accuracy =   0.513500       |  0.513500
#             precision =  0.749772  |   recall =    0.513500   |  f1 =    0.362813
#
#
#  ================ x2face CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (1.9751_0.9738_0.9852)_fold_0/step/bestcapsule_test_acc_9400_0.985200.pt
#   FOLD: 0
#             accuracy =   0.820000       |  0.820000
#             precision =  0.860943  |   recall =    0.820000   |  f1 =    0.814746
# Test image dataset:  10000
#             pt file:  (1.9756_0.9760_0.9859)_fold_1/step/bestcapsule_test_acc_14600_0.985900.pt
#   FOLD: 1
#             accuracy =   0.714300       |  0.714300
#             precision =  0.817327  |   recall =    0.714300   |  f1 =    0.689062
# Test image dataset:  10000
#             pt file:  (1.9845_0.9823_0.9831)_fold_2/step/bestcapsule_test_acc_14400_0.983100.pt
#   FOLD: 2
#             accuracy =   0.759100       |  0.759100
#             precision =  0.825998  |   recall =    0.759100   |  f1 =    0.746073
# Test image dataset:  10000
#             pt file:  (1.9866_0.9693_0.9835)_fold_3/step/bestcapsule_test_acc_11200_0.983500.pt
#   FOLD: 3
#             accuracy =   0.816300       |  0.816300
#             precision =  0.836498  |   recall =    0.816300   |  f1 =    0.813501
# Test image dataset:  10000
#             pt file:  (1.9814_0.9780_0.9829)_fold_4/step/bestcapsule_test_acc_11200_0.982900.pt
#   FOLD: 4
#             accuracy =   0.747400       |  0.747400
#             precision =  0.824235  |   recall =    0.747400   |  f1 =    0.731493
