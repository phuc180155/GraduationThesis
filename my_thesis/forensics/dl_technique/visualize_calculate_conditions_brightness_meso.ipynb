# %%
from model.cnn.xception_net.model import xception
from model.cnn.mesonet4.model import mesonet
import torch
from module.train_torch import calculate_metric
import random
import numpy as np
import os
import torch.nn as nn
from glob import glob
from tqdm import tqdm
from os.path import join
from utils.util import get_test_metric_by_step2
from operator import truediv
import os, sys
from random import shuffle
import os.path as osp

import torch
from torchvision import datasets, transforms

from dataloader.utils import make_weights_for_balanced_classes, make_weights_for_balanced_classes_2
from dataloader.dual_fft_dataset import DualFFTMagnitudeFeatureDataset, DualFFTMagnitudeImageDataset, TripleFFTMagnitudePhaseDataset
from dataloader.pairwise_dual_fft_dataset import PairwiseDualFFTMagnitudeFeatureDataset, PairwiseDualFFTMagnitudeImageDataset
from dataloader.pairwise_single_fft_dataset import PairwiseSingleFFTMagnitudeImageDataset
from dataloader.pairwise_triple_fft_dataset import PairwiseTripleFFTMagnitudePhaseDataset
from dataloader.triplewise_dual_fft_dataset import TriplewiseDualFFTMagnitudeImageDataset
from dataloader.transform import transform_method

torch.manual_seed(0)
random.seed(0)
np.random.seed(0)

def eval_kfold_image_stream(model ,dataloader, device, criterion, adj_brightness=1.0, adj_contrast=1.0 ):
    loss = 0
    mac_accuracy = 0
    model.eval()
    y_label = []
    y_pred_label = []
    with torch.no_grad():
        for inputs, labels in dataloader:
            # Push to device
            y_label.extend(labels.cpu().numpy().astype(np.float64))
            inputs, labels = inputs.float().to(device), labels.float().to(device)

            # Forward network
            logps = model.forward(inputs)
            if len(logps.shape) == 2:
                logps = logps.squeeze(dim=1)

            # Loss in a batch
            batch_loss = criterion(logps, labels)
            # Cumulate into running val loss
            loss += batch_loss.item()

            # Find accuracy
            equals = (labels == (logps > 0.5))
            mac_accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
            #
            logps_cpu = logps.cpu().numpy()
            pred_label = (logps_cpu > 0.5)
            y_pred_label.extend(pred_label)
            
    assert len(y_label) == len(y_pred_label), "Bug"
    ######## Calculate metrics:
    loss /= len(dataloader)
    mac_accuracy /= len(dataloader)
    # built-in methods for calculating metrics
    mic_accuracy, reals, fakes, micros, macros = calculate_metric(y_label, y_pred_label)
    return loss, mac_accuracy, mic_accuracy, reals, fakes, micros, macros

def generate_test_dataloader_single_cnn_stream_for_kfold(test_dir, image_size, batch_size, num_workers, adj_brightness=1.0, adj_contrast=1.0):
    transform_fwd = transforms.Compose([transforms.Resize((image_size,image_size)),\
                                        transforms.Lambda(lambda img :transforms.functional.adjust_brightness(img,adj_brightness)),\
                                        transforms.Lambda(lambda img :transforms.functional.adjust_contrast(img,adj_contrast)),\
                                        transforms.ToTensor(),\
                                        transforms.Normalize(mean=[0.485, 0.456, 0.406],\
                                                             std=[0.229, 0.224, 0.225]),\
                                        ])
    # Make dataset using built-in ImageFolder function of torch
    test_dataset = datasets.ImageFolder(test_dir, transform=transform_fwd)
    assert test_dataset, "Test Dataset is empty!"
    print("Test image dataset: ", test_dataset.__len__())
    # Make dataloader
    dataloader_test = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return dataloader_test

################### FROM DEEPFAKE TO OTHER DATASET:
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
device = torch.device('cuda')

test_dir_template = "/mnt/disk1/doan/phucnp/Dataset/my_extend_data/extend_data_train/{}/test"

checkpoints = {
    "deepfake": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/deepfake/kfold_meso4/lr6e-05_batch16_esnone_lossbce_nf5_trick1_seed0_drmlp0.0_aug0",
    "faceswap_2d": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/faceswap_2d/kfold_meso4/lr0.0002_batch16_esnone_lossbce_nf5_trick1_seed0_drmlp0.0_aug0",
    "3dmm": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/3dmm/kfold_meso4/lr0.0002_batch16_esnone_lossbce_nf5_trick1_seed0_drmlp0.0_aug0",
    "faceswap_3d": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/faceswap_3d/kfold_meso4/lr0.0002_batch16_esnone_lossbce_nf5_trick1_seed0_drmlp0.0_aug0",
    "monkey": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/monkey/kfold_meso4/lr6e-05_batch16_esnone_lossbce_nf5_trick1_seed0_drmlp0.0_aug0",
    "reenact": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/reenact/kfold_meso4/lr0.0002_batch16_esnone_lossbce_nf5_trick1_seed0_drmlp0.0_aug0",
    "stargan": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/stargan/kfold_meso4/lr0.0002_batch16_esnone_lossbce_nf5_trick1_seed0_drmlp0.0_aug0",
    "x2face": "/mnt/disk1/doan/phucnp/Graduation_Thesis/my_thesis/forensics/dl_technique/checkpoint/extend_data/x2face/kfold_meso4/lr0.0002_batch16_esnone_lossbce_nf5_trick1_seed0_drmlp0.0_aug0"
}

brightnesses = [1.0, 0.5, 0.75, 1.5, 2.0]
contrast = 1.0

for brightness in brightnesses:
    print("\n*********************************************************")
    print("             BRIGHTNESS: ", brightness)
    for technique in ['deepfake', '3dmm', 'faceswap_2d', 'faceswap_3d', 'monkey', 'reenact', 'stargan', 'x2face']:
        checkpoint = checkpoints[technique]
        print("\n\n ================ {} CHECKPOINT ================".format(technique))
        my_break = False
        
        for fold_dir in sorted(os.listdir(checkpoint), key=lambda dir: int(dir[-1])):
            pt_file = glob(join(checkpoint, fold_dir, 'step', 'best_test_acc*'))[0]

            fold_id = pt_file.split('/')[-3][-1]

            model_ = mesonet(image_size=128)
            model_.load_state_dict(torch.load(pt_file))
            model_ = model_.to(device)
            
            batch_size = 16

            test_dir = test_dir_template.format(technique)
            dataloader_test = generate_test_dataloader_single_cnn_stream_for_kfold(test_dir, 128, batch_size, 4, adj_brightness=brightness, adj_contrast=contrast)

            criterion = nn.BCELoss().to(device)
            ####
            loss, mac_acc, mic_acc, reals, fakes, micros, macros = eval_kfold_image_stream(model_, dataloader_test, device, criterion)
            print("            pt file: ", '/'.join(pt_file.split('/')[-3:]))
            print("  FOLD: {}   ".format(fold_id))
            print("            accuracy =   {:.6f}       |  {:6f}".format(mic_acc, mac_acc))
            print("            precision =  {:.6f}  |   recall =    {:.6f}   |  f1 =    {:.6f}".format(macros[0], macros[1], macros[2]))

            if brightness == 1.0:
                step_ckcpoint = osp.split(pt_file)[0]
                step = int(osp.basename(pt_file).split('_')[-2])
                pairwise = True if 'pairwise' in pt_file else False
                metrics, bestloss = get_test_metric_by_step2(step_ckcpoint=step_ckcpoint, steps=step, pairwise=pairwise)
                acc, pre, rec, f1 = metrics['best_test_acc']['acc'], metrics['best_test_acc']['pre'], metrics['best_test_acc']['rec'], metrics['best_test_acc']['f1']

                # if abs(round(loss, 4) - round(bestloss, 4)) > 0.001:
                #     print("         Error in loss: {}, {}".format(loss, bestloss))
                #     my_break = True
                if abs(round(mic_acc, 4) - round(acc, 4)) > 0.001:
                    print("         Error in acc: {}, {}".format(mic_acc, acc))
                    my_break = True
                if abs(round(macros[0], 4) - round(pre, 4)) > 0.001:
                    print("         Error in pre: {}, {}".format(macros[0], pre))
                    my_break = True
                if abs(round(macros[1], 4) - round(rec, 4)) > 0.001:
                    print("         Error in rec: {}, {}".format(macros[1], rec))
                    my_break = True
                if abs(round(macros[2], 4) - round(f1, 4)) > 0.001:
                    print("         Error in f1: {}, {}".format(macros[2], f1))
                    my_break = True

                if my_break:
                    break

        if my_break:
            break

    if my_break:
        break
# Out:
# *********************************************************
#              BRIGHTNESS:  1.0
#
#
#  ================ deepfake CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.0888_0.9064_0.9525)_fold_0/step/best_test_acc_18000_0.952500.pt
#   FOLD: 0
#             accuracy =   0.952500       |  0.952500
#             precision =  0.955342  |   recall =    0.952500   |  f1 =    0.952426
# Test image dataset:  10000
#             pt file:  (0.0901_0.9372_0.9434)_fold_1/step/best_test_acc_16200_0.943400.pt
#   FOLD: 1
#             accuracy =   0.943400       |  0.943400
#             precision =  0.943550  |   recall =    0.943400   |  f1 =    0.943395
# Test image dataset:  10000
#             pt file:  (0.0982_0.8780_0.8948)_fold_2/step/best_test_acc_10800_0.894800.pt
#   FOLD: 2
#             accuracy =   0.894800       |  0.894800
#             precision =  0.895156  |   recall =    0.894800   |  f1 =    0.894776
# Test image dataset:  10000
#             pt file:  (0.0983_0.9043_0.9128)_fold_3/step/best_test_acc_17200_0.912800.pt
#   FOLD: 3
#             accuracy =   0.912800       |  0.912800
#             precision =  0.919416  |   recall =    0.912800   |  f1 =    0.912455
# Test image dataset:  10000
#             pt file:  (0.2025_0.8786_0.9478)_fold_4/step/best_test_acc_17000_0.947800.pt
#   FOLD: 4
#             accuracy =   0.947800       |  0.947800
#             precision =  0.950374  |   recall =    0.947800   |  f1 =    0.947725
#
#
#  ================ 3dmm CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.0198_0.9927_0.9927)_fold_0/step/best_test_acc_6200_0.992700.pt
#   FOLD: 0
#             accuracy =   0.992700       |  0.992700
#             precision =  0.992773  |   recall =    0.992700   |  f1 =    0.992700
# Test image dataset:  10000
#             pt file:  (0.0584_0.9768_0.9768)_fold_1/step/best_test_acc_11600_0.976800.pt
#   FOLD: 1
#             accuracy =   0.976800       |  0.976800
#             precision =  0.977829  |   recall =    0.976800   |  f1 =    0.976788
# Test image dataset:  10000
#             pt file:  (0.0175_0.9921_0.9921)_fold_2/step/best_test_acc_20000_0.992100.pt
#   FOLD: 2
#             accuracy =   0.992100       |  0.992100
#             precision =  0.992106  |   recall =    0.992100   |  f1 =    0.992100
# Test image dataset:  10000
#             pt file:  (0.0128_0.9971_0.9971)_fold_3/step/best_test_acc_12000_0.997100.pt
#   FOLD: 3
#             accuracy =   0.997100       |  0.997100
#             precision =  0.997103  |   recall =    0.997100   |  f1 =    0.997100
# Test image dataset:  10000
#             pt file:  (0.0309_0.9910_0.9910)_fold_4/step/best_test_acc_12000_0.991000.pt
#   FOLD: 4
#             accuracy =   0.991000       |  0.991000
#             precision =  0.991091  |   recall =    0.991000   |  f1 =    0.991000
#
#
#  ================ faceswap_2d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.3051_0.5196_0.5760)_fold_0/step/best_test_acc_16000_0.576000.pt
#   FOLD: 0
#             accuracy =   0.576000       |  0.576000
#             precision =  0.576011  |   recall =    0.576000   |  f1 =    0.575985
# Test image dataset:  10000
#             pt file:  (0.9974_0.5000_0.5044)_fold_1/step/best_test_acc_8400_0.504400.pt
#   FOLD: 1
#             accuracy =   0.504400       |  0.504400
#             precision =  0.608954  |   recall =    0.504400   |  f1 =    0.347977
# Test image dataset:  10000
#             pt file:  (0.2139_0.5051_0.5352)_fold_2/step/best_test_acc_5800_0.535200.pt
#   FOLD: 2
#             accuracy =   0.535200       |  0.535200
#             precision =  0.538148  |   recall =    0.535200   |  f1 =    0.526043
# Test image dataset:  10000
#             pt file:  (0.1882_0.5182_0.5268)_fold_3/step/best_test_acc_5000_0.526800.pt
#   FOLD: 3
#             accuracy =   0.526800       |  0.526800
#             precision =  0.609928  |   recall =    0.526800   |  f1 =    0.416486
# Test image dataset:  10000
#             pt file:  (0.7512_0.4999_0.5000)_fold_4/step/best_test_acc_400_0.500000.pt
#   FOLD: 4
#             accuracy =   0.500000       |  0.500000
#             precision =  0.250000  |   recall =    0.500000   |  f1 =    0.333333
#
#
#  ================ faceswap_3d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.7323_0.5000_0.5084)_fold_0/step/best_test_acc_19800_0.508400.pt
#   FOLD: 0
#             accuracy =   0.508400       |  0.508400
#             precision =  0.549495  |   recall =    0.508400   |  f1 =    0.379629
# Test image dataset:  10000
#             pt file:  (0.5359_0.5008_0.5573)_fold_1/step/best_test_acc_1600_0.557300.pt
#   FOLD: 1
#             accuracy =   0.557300       |  0.557300
#             precision =  0.565001  |   recall =    0.557300   |  f1 =    0.543788
# Test image dataset:  10000
#             pt file:  (0.9268_0.5000_0.5002)_fold_2/step/best_test_acc_6000_0.500200.pt
#   FOLD: 2
#             accuracy =   0.500200       |  0.500200
#             precision =  0.583383  |   recall =    0.500200   |  f1 =    0.334132
# Test image dataset:  10000
#             pt file:  (0.8368_0.5000_0.5000)_fold_3/step/best_test_acc_200_0.500000.pt
#   FOLD: 3
#             accuracy =   0.500000       |  0.500000
#             precision =  0.250000  |   recall =    0.500000   |  f1 =    0.333333
# Test image dataset:  10000
#             pt file:  (0.8034_0.5166_0.5493)_fold_4/step/best_test_acc_7200_0.549300.pt
#   FOLD: 4
#             accuracy =   0.549300       |  0.549300
#             precision =  0.550932  |   recall =    0.549300   |  f1 =    0.545661
#
#
#  ================ monkey CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.6628_0.5568_0.5937)_fold_0/step/best_test_acc_1200_0.593700.pt
#   FOLD: 0
#             accuracy =   0.593700       |  0.593700
#             precision =  0.596118  |   recall =    0.593700   |  f1 =    0.591129
# Test image dataset:  10000
#             pt file:  (0.6596_0.5765_0.5903)_fold_1/step/best_test_acc_1400_0.590300.pt
#   FOLD: 1
#             accuracy =   0.590300       |  0.590300
#             precision =  0.590539  |   recall =    0.590300   |  f1 =    0.590029
# Test image dataset:  10000
#             pt file:  (0.6675_0.5937_0.5937)_fold_2/step/best_test_acc_1200_0.593700.pt
#   FOLD: 2
#             accuracy =   0.593700       |  0.593700
#             precision =  0.597294  |   recall =    0.593700   |  f1 =    0.589913
# Test image dataset:  10000
#             pt file:  (0.6583_0.5945_0.6033)_fold_3/step/best_test_acc_1400_0.603300.pt
#   FOLD: 3
#             accuracy =   0.603300       |  0.603300
#             precision =  0.606912  |   recall =    0.603300   |  f1 =    0.599921
# Test image dataset:  10000
#             pt file:  (0.6572_0.5509_0.5817)_fold_4/step/best_test_acc_1600_0.581700.pt
#   FOLD: 4
#             accuracy =   0.581700       |  0.581700
#             precision =  0.583565  |   recall =    0.581700   |  f1 =    0.579353
#
#
#  ================ reenact CHECKPOINT ================
# Test image dataset:  9566
#             pt file:  (0.0100_0.9989_0.9989)_fold_0/step/best_test_acc_11200_0.998850.pt
#   FOLD: 0
#             accuracy =   0.998850       |  0.998850
#             precision =  0.998798  |   recall =    0.998900   |  f1 =    0.998848
# Test image dataset:  9566
#             pt file:  (0.0188_0.9990_0.9990)_fold_1/step/best_test_acc_16200_0.998955.pt
#   FOLD: 1
#             accuracy =   0.998955       |  0.998955
#             precision =  0.998982  |   recall =    0.998924   |  f1 =    0.998952
# Test image dataset:  9566
#             pt file:  (0.0098_0.9999_0.9999)_fold_2/step/best_test_acc_12800_0.999895.pt
#   FOLD: 2
#             accuracy =   0.999895       |  0.999895
#             precision =  0.999900  |   recall =    0.999890   |  f1 =    0.999895
# Test image dataset:  9566
#             pt file:  (0.0034_0.9994_0.9997)_fold_3/step/best_test_acc_17400_0.999686.pt
#   FOLD: 3
#             accuracy =   0.999686       |  0.999686
#             precision =  0.999681  |   recall =    0.999690   |  f1 =    0.999686
# Test image dataset:  9566
#             pt file:  (0.0040_0.9987_0.9993)_fold_4/step/best_test_acc_12800_0.999268.pt
#   FOLD: 4
#             accuracy =   0.999268       |  0.999268
#             precision =  0.999244  |   recall =    0.999290   |  f1 =    0.999267
#
#
#  ================ stargan CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.5570_0.8461_0.8461)_fold_0/step/best_test_acc_18600_0.846100.pt
#   FOLD: 0
#             accuracy =   0.846100       |  0.846100
#             precision =  0.846210  |   recall =    0.846100   |  f1 =    0.846088
# Test image dataset:  10000
#             pt file:  (0.2329_0.9104_0.9165)_fold_1/step/best_test_acc_16400_0.916500.pt
#   FOLD: 1
#             accuracy =   0.916500       |  0.916500
#             precision =  0.916547  |   recall =    0.916500   |  f1 =    0.916498
# Test image dataset:  10000
#             pt file:  (0.2943_0.9251_0.9251)_fold_2/step/best_test_acc_3400_0.925100.pt
#   FOLD: 2
#             accuracy =   0.925100       |  0.925100
#             precision =  0.927992  |   recall =    0.925100   |  f1 =    0.924973
# Test image dataset:  10000
#             pt file:  (0.5558_0.7556_0.7806)_fold_3/step/best_test_acc_14400_0.780600.pt
#   FOLD: 3
#             accuracy =   0.780600       |  0.780600
#             precision =  0.824552  |   recall =    0.780600   |  f1 =    0.772912
# Test image dataset:  10000
#             pt file:  (0.4826_0.6937_0.7180)_fold_4/step/best_test_acc_7400_0.718000.pt
#   FOLD: 4
#             accuracy =   0.718000       |  0.718000
#             precision =  0.801562  |   recall =    0.718000   |  f1 =    0.697011
#
#
#  ================ x2face CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.2236_0.8271_0.8483)_fold_0/step/best_test_acc_200_0.848300.pt
#   FOLD: 0
#             accuracy =   0.848300       |  0.848300
#             precision =  0.857663  |   recall =    0.848300   |  f1 =    0.847301
# Test image dataset:  10000
#             pt file:  (0.1875_0.8138_0.8635)_fold_1/step/best_test_acc_8600_0.863500.pt
#   FOLD: 1
#             accuracy =   0.863500       |  0.863500
#             precision =  0.866429  |   recall =    0.863500   |  f1 =    0.863227
# Test image dataset:  10000
#             pt file:  (0.1208_0.8860_0.9010)_fold_2/step/best_test_acc_11000_0.901000.pt
#   FOLD: 2
#             accuracy =   0.901000       |  0.901000
#             precision =  0.903531  |   recall =    0.901000   |  f1 =    0.900845
# Test image dataset:  10000
#             pt file:  (0.2645_0.7685_0.8545)_fold_3/step/best_test_acc_600_0.854500.pt
#   FOLD: 3
#             accuracy =   0.854500       |  0.854500
#             precision =  0.854736  |   recall =    0.854500   |  f1 =    0.854476
# Test image dataset:  10000
#             pt file:  (0.2340_0.7916_0.8721)_fold_4/step/best_test_acc_1200_0.872100.pt
#   FOLD: 4
#             accuracy =   0.872100       |  0.872100
#             precision =  0.873922  |   recall =    0.872100   |  f1 =    0.871944
#
# *********************************************************
#              BRIGHTNESS:  0.5
#
#
#  ================ deepfake CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.0888_0.9064_0.9525)_fold_0/step/best_test_acc_18000_0.952500.pt
#   FOLD: 0
#             accuracy =   0.882200       |  0.882200
#             precision =  0.896203  |   recall =    0.882200   |  f1 =    0.881150
# Test image dataset:  10000
#             pt file:  (0.0901_0.9372_0.9434)_fold_1/step/best_test_acc_16200_0.943400.pt
#   FOLD: 1
#             accuracy =   0.770800       |  0.770800
#             precision =  0.773761  |   recall =    0.770800   |  f1 =    0.770179
# Test image dataset:  10000
#             pt file:  (0.0982_0.8780_0.8948)_fold_2/step/best_test_acc_10800_0.894800.pt
#   FOLD: 2
#             accuracy =   0.712800       |  0.712800
#             precision =  0.719926  |   recall =    0.712800   |  f1 =    0.710455
# Test image dataset:  10000
#             pt file:  (0.0983_0.9043_0.9128)_fold_3/step/best_test_acc_17200_0.912800.pt
#   FOLD: 3
#             accuracy =   0.887500       |  0.887500
#             precision =  0.890374  |   recall =    0.887500   |  f1 =    0.887293
# Test image dataset:  10000
#             pt file:  (0.2025_0.8786_0.9478)_fold_4/step/best_test_acc_17000_0.947800.pt
#   FOLD: 4
#             accuracy =   0.844700       |  0.844700
#             precision =  0.848632  |   recall =    0.844700   |  f1 =    0.844261
#
#
#  ================ 3dmm CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.0198_0.9927_0.9927)_fold_0/step/best_test_acc_6200_0.992700.pt
#   FOLD: 0
#             accuracy =   0.990800       |  0.990800
#             precision =  0.990835  |   recall =    0.990800   |  f1 =    0.990800
# Test image dataset:  10000
#             pt file:  (0.0584_0.9768_0.9768)_fold_1/step/best_test_acc_11600_0.976800.pt
#   FOLD: 1
#             accuracy =   0.822600       |  0.822600
#             precision =  0.868938  |   recall =    0.822600   |  f1 =    0.816849
# Test image dataset:  10000
#             pt file:  (0.0175_0.9921_0.9921)_fold_2/step/best_test_acc_20000_0.992100.pt
#   FOLD: 2
#             accuracy =   0.982700       |  0.982700
#             precision =  0.983252  |   recall =    0.982700   |  f1 =    0.982695
# Test image dataset:  10000
#             pt file:  (0.0128_0.9971_0.9971)_fold_3/step/best_test_acc_12000_0.997100.pt
#   FOLD: 3
#             accuracy =   0.996200       |  0.996200
#             precision =  0.996208  |   recall =    0.996200   |  f1 =    0.996200
# Test image dataset:  10000
#             pt file:  (0.0309_0.9910_0.9910)_fold_4/step/best_test_acc_12000_0.991000.pt
#   FOLD: 4
#             accuracy =   0.993400       |  0.993400
#             precision =  0.993420  |   recall =    0.993400   |  f1 =    0.993400
#
#
#  ================ faceswap_2d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.3051_0.5196_0.5760)_fold_0/step/best_test_acc_16000_0.576000.pt
#   FOLD: 0
#             accuracy =   0.527600       |  0.527600
#             precision =  0.528449  |   recall =    0.527600   |  f1 =    0.524047
# Test image dataset:  10000
#             pt file:  (0.9974_0.5000_0.5044)_fold_1/step/best_test_acc_8400_0.504400.pt
#   FOLD: 1
#             accuracy =   0.522700       |  0.522700
#             precision =  0.526689  |   recall =    0.522700   |  f1 =    0.504173
# Test image dataset:  10000
#             pt file:  (0.2139_0.5051_0.5352)_fold_2/step/best_test_acc_5800_0.535200.pt
#   FOLD: 2
#             accuracy =   0.496700       |  0.496700
#             precision =  0.481161  |   recall =    0.496700   |  f1 =    0.365956
# Test image dataset:  10000
#             pt file:  (0.1882_0.5182_0.5268)_fold_3/step/best_test_acc_5000_0.526800.pt
#   FOLD: 3
#             accuracy =   0.515700       |  0.515700
#             precision =  0.556096  |   recall =    0.515700   |  f1 =    0.409368
# Test image dataset:  10000
#             pt file:  (0.7512_0.4999_0.5000)_fold_4/step/best_test_acc_400_0.500000.pt
#   FOLD: 4
#             accuracy =   0.500000       |  0.500000
#             precision =  0.250000  |   recall =    0.500000   |  f1 =    0.333333
#
#
#  ================ faceswap_3d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.7323_0.5000_0.5084)_fold_0/step/best_test_acc_19800_0.508400.pt
#   FOLD: 0
#             accuracy =   0.500000       |  0.500000
#             precision =  0.250000  |   recall =    0.500000   |  f1 =    0.333333
# Test image dataset:  10000
#             pt file:  (0.5359_0.5008_0.5573)_fold_1/step/best_test_acc_1600_0.557300.pt
#   FOLD: 1
#             accuracy =   0.528700       |  0.528700
#             precision =  0.649077  |   recall =    0.528700   |  f1 =    0.409494
# Test image dataset:  10000
#             pt file:  (0.9268_0.5000_0.5002)_fold_2/step/best_test_acc_6000_0.500200.pt
#   FOLD: 2
#             accuracy =   0.500000       |  0.500000
#             precision =  0.250000  |   recall =    0.500000   |  f1 =    0.333333
# Test image dataset:  10000
#             pt file:  (0.8368_0.5000_0.5000)_fold_3/step/best_test_acc_200_0.500000.pt
#   FOLD: 3
#             accuracy =   0.500000       |  0.500000
#             precision =  0.250000  |   recall =    0.500000   |  f1 =    0.333333
# Test image dataset:  10000
#             pt file:  (0.8034_0.5166_0.5493)_fold_4/step/best_test_acc_7200_0.549300.pt
#   FOLD: 4
#             accuracy =   0.505500       |  0.505500
#             precision =  0.535893  |   recall =    0.505500   |  f1 =    0.372707
#
#
#  ================ monkey CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.6628_0.5568_0.5937)_fold_0/step/best_test_acc_1200_0.593700.pt
#   FOLD: 0
#             accuracy =   0.509500       |  0.509500
#             precision =  0.624217  |   recall =    0.509500   |  f1 =    0.362258
# Test image dataset:  10000
#             pt file:  (0.6596_0.5765_0.5903)_fold_1/step/best_test_acc_1400_0.590300.pt
#   FOLD: 1
#             accuracy =   0.506300       |  0.506300
#             precision =  0.564868  |   recall =    0.506300   |  f1 =    0.362375
# Test image dataset:  10000
#             pt file:  (0.6675_0.5937_0.5937)_fold_2/step/best_test_acc_1200_0.593700.pt
#   FOLD: 2
#             accuracy =   0.509600       |  0.509600
#             precision =  0.581423  |   recall =    0.509600   |  f1 =    0.370859
# Test image dataset:  10000
#             pt file:  (0.6583_0.5945_0.6033)_fold_3/step/best_test_acc_1400_0.603300.pt
#   FOLD: 3
#             accuracy =   0.503400       |  0.503400
#             precision =  0.625856  |   recall =    0.503400   |  f1 =    0.343776
# Test image dataset:  10000
#             pt file:  (0.6572_0.5509_0.5817)_fold_4/step/best_test_acc_1600_0.581700.pt
#   FOLD: 4
#             accuracy =   0.516900       |  0.516900
#             precision =  0.610290  |   recall =    0.516900   |  f1 =    0.387168
#
#
#  ================ reenact CHECKPOINT ================
# Test image dataset:  9566
#             pt file:  (0.0100_0.9989_0.9989)_fold_0/step/best_test_acc_11200_0.998850.pt
#   FOLD: 0
#             accuracy =   0.962471       |  0.962479
#             precision =  0.962665  |   recall =    0.962142   |  f1 =    0.962374
# Test image dataset:  9566
#             pt file:  (0.0188_0.9990_0.9990)_fold_1/step/best_test_acc_16200_0.998955.pt
#   FOLD: 1
#             accuracy =   0.522371       |  0.522262
#             precision =  0.261267  |   recall =    0.499700   |  f1 =    0.343130
# Test image dataset:  9566
#             pt file:  (0.0098_0.9999_0.9999)_fold_2/step/best_test_acc_12800_0.999895.pt
#   FOLD: 2
#             accuracy =   0.554568       |  0.554452
#             precision =  0.738526  |   recall =    0.533608   |  f1 =    0.416675
# Test image dataset:  9566
#             pt file:  (0.0034_0.9994_0.9997)_fold_3/step/best_test_acc_17400_0.999686.pt
#   FOLD: 3
#             accuracy =   0.574012       |  0.573922
#             precision =  0.773473  |   recall =    0.553786   |  f1 =    0.452610
# Test image dataset:  9566
#             pt file:  (0.0040_0.9987_0.9993)_fold_4/step/best_test_acc_12800_0.999268.pt
#   FOLD: 4
#             accuracy =   0.699979       |  0.699892
#             precision =  0.794150  |   recall =    0.686624   |  f1 =    0.664418
#
#
#  ================ stargan CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.5570_0.8461_0.8461)_fold_0/step/best_test_acc_18600_0.846100.pt
#   FOLD: 0
#             accuracy =   0.577900       |  0.577900
#             precision =  0.582823  |   recall =    0.577900   |  f1 =    0.571533
# Test image dataset:  10000
#             pt file:  (0.2329_0.9104_0.9165)_fold_1/step/best_test_acc_16400_0.916500.pt
#   FOLD: 1
#             accuracy =   0.645400       |  0.645400
#             precision =  0.684167  |   recall =    0.645400   |  f1 =    0.625703
# Test image dataset:  10000
#             pt file:  (0.2943_0.9251_0.9251)_fold_2/step/best_test_acc_3400_0.925100.pt
#   FOLD: 2
#             accuracy =   0.598900       |  0.598900
#             precision =  0.610452  |   recall =    0.598900   |  f1 =    0.588131
# Test image dataset:  10000
#             pt file:  (0.5558_0.7556_0.7806)_fold_3/step/best_test_acc_14400_0.780600.pt
#   FOLD: 3
#             accuracy =   0.536800       |  0.536800
#             precision =  0.580607  |   recall =    0.536800   |  f1 =    0.463972
# Test image dataset:  10000
#             pt file:  (0.4826_0.6937_0.7180)_fold_4/step/best_test_acc_7400_0.718000.pt
#   FOLD: 4
#             accuracy =   0.509800       |  0.509800
#             precision =  0.569850  |   recall =    0.509800   |  f1 =    0.375601
#
#
#  ================ x2face CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.2236_0.8271_0.8483)_fold_0/step/best_test_acc_200_0.848300.pt
#   FOLD: 0
#             accuracy =   0.542600       |  0.542600
#             precision =  0.716042  |   recall =    0.542600   |  f1 =    0.427746
# Test image dataset:  10000
#             pt file:  (0.1875_0.8138_0.8635)_fold_1/step/best_test_acc_8600_0.863500.pt
#   FOLD: 1
#             accuracy =   0.779900       |  0.779900
#             precision =  0.794714  |   recall =    0.779900   |  f1 =    0.777099
# Test image dataset:  10000
#             pt file:  (0.1208_0.8860_0.9010)_fold_2/step/best_test_acc_11000_0.901000.pt
#   FOLD: 2
#             accuracy =   0.631200       |  0.631200
#             precision =  0.785175  |   recall =    0.631200   |  f1 =    0.573650
# Test image dataset:  10000
#             pt file:  (0.2645_0.7685_0.8545)_fold_3/step/best_test_acc_600_0.854500.pt
#   FOLD: 3
#             accuracy =   0.531400       |  0.531400
#             precision =  0.654750  |   recall =    0.531400   |  f1 =    0.414782
# Test image dataset:  10000
#             pt file:  (0.2340_0.7916_0.8721)_fold_4/step/best_test_acc_1200_0.872100.pt
#   FOLD: 4
#             accuracy =   0.565500       |  0.565500
#             precision =  0.566907  |   recall =    0.565500   |  f1 =    0.563204
#
# *********************************************************
#              BRIGHTNESS:  0.75
#
#
#  ================ deepfake CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.0888_0.9064_0.9525)_fold_0/step/best_test_acc_18000_0.952500.pt
#   FOLD: 0
#             accuracy =   0.946200       |  0.946200
#             precision =  0.948657  |   recall =    0.946200   |  f1 =    0.946126
# Test image dataset:  10000
#             pt file:  (0.0901_0.9372_0.9434)_fold_1/step/best_test_acc_16200_0.943400.pt
#   FOLD: 1
#             accuracy =   0.906300       |  0.906300
#             precision =  0.912018  |   recall =    0.906300   |  f1 =    0.905974
# Test image dataset:  10000
#             pt file:  (0.0982_0.8780_0.8948)_fold_2/step/best_test_acc_10800_0.894800.pt
#   FOLD: 2
#             accuracy =   0.826700       |  0.826700
#             precision =  0.830094  |   recall =    0.826700   |  f1 =    0.826253
# Test image dataset:  10000
#             pt file:  (0.0983_0.9043_0.9128)_fold_3/step/best_test_acc_17200_0.912800.pt
#   FOLD: 3
#             accuracy =   0.929500       |  0.929500
#             precision =  0.930822  |   recall =    0.929500   |  f1 =    0.929446
# Test image dataset:  10000
#             pt file:  (0.2025_0.8786_0.9478)_fold_4/step/best_test_acc_17000_0.947800.pt
#   FOLD: 4
#             accuracy =   0.927100       |  0.927100
#             precision =  0.929464  |   recall =    0.927100   |  f1 =    0.927000
#
#
#  ================ 3dmm CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.0198_0.9927_0.9927)_fold_0/step/best_test_acc_6200_0.992700.pt
#   FOLD: 0
#             accuracy =   0.991400       |  0.991400
#             precision =  0.991466  |   recall =    0.991400   |  f1 =    0.991400
# Test image dataset:  10000
#             pt file:  (0.0584_0.9768_0.9768)_fold_1/step/best_test_acc_11600_0.976800.pt
#   FOLD: 1
#             accuracy =   0.940300       |  0.940300
#             precision =  0.946625  |   recall =    0.940300   |  f1 =    0.940088
# Test image dataset:  10000
#             pt file:  (0.0175_0.9921_0.9921)_fold_2/step/best_test_acc_20000_0.992100.pt
#   FOLD: 2
#             accuracy =   0.992300       |  0.992300
#             precision =  0.992355  |   recall =    0.992300   |  f1 =    0.992300
# Test image dataset:  10000
#             pt file:  (0.0128_0.9971_0.9971)_fold_3/step/best_test_acc_12000_0.997100.pt
#   FOLD: 3
#             accuracy =   0.996800       |  0.996800
#             precision =  0.996808  |   recall =    0.996800   |  f1 =    0.996800
# Test image dataset:  10000
#             pt file:  (0.0309_0.9910_0.9910)_fold_4/step/best_test_acc_12000_0.991000.pt
#   FOLD: 4
#             accuracy =   0.991400       |  0.991400
#             precision =  0.991453  |   recall =    0.991400   |  f1 =    0.991400
#
#
#  ================ faceswap_2d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.3051_0.5196_0.5760)_fold_0/step/best_test_acc_16000_0.576000.pt
#   FOLD: 0
#             accuracy =   0.560500       |  0.560500
#             precision =  0.571471  |   recall =    0.560500   |  f1 =    0.542960
# Test image dataset:  10000
#             pt file:  (0.9974_0.5000_0.5044)_fold_1/step/best_test_acc_8400_0.504400.pt
#   FOLD: 1
#             accuracy =   0.509500       |  0.509500
#             precision =  0.552284  |   recall =    0.509500   |  f1 =    0.383348
# Test image dataset:  10000
#             pt file:  (0.2139_0.5051_0.5352)_fold_2/step/best_test_acc_5800_0.535200.pt
#   FOLD: 2
#             accuracy =   0.521800       |  0.521800
#             precision =  0.523132  |   recall =    0.521800   |  f1 =    0.514813
# Test image dataset:  10000
#             pt file:  (0.1882_0.5182_0.5268)_fold_3/step/best_test_acc_5000_0.526800.pt
#   FOLD: 3
#             accuracy =   0.580900       |  0.580900
#             precision =  0.592930  |   recall =    0.580900   |  f1 =    0.566883
# Test image dataset:  10000
#             pt file:  (0.7512_0.4999_0.5000)_fold_4/step/best_test_acc_400_0.500000.pt
#   FOLD: 4
#             accuracy =   0.500000       |  0.500000
#             precision =  0.250000  |   recall =    0.500000   |  f1 =    0.333333
#
#
#  ================ faceswap_3d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.7323_0.5000_0.5084)_fold_0/step/best_test_acc_19800_0.508400.pt
#   FOLD: 0
#             accuracy =   0.502300       |  0.502300
#             precision =  0.569857  |   recall =    0.502300   |  f1 =    0.343604
# Test image dataset:  10000
#             pt file:  (0.5359_0.5008_0.5573)_fold_1/step/best_test_acc_1600_0.557300.pt
#   FOLD: 1
#             accuracy =   0.537800       |  0.537800
#             precision =  0.584440  |   recall =    0.537800   |  f1 =    0.463751
# Test image dataset:  10000
#             pt file:  (0.9268_0.5000_0.5002)_fold_2/step/best_test_acc_6000_0.500200.pt
#   FOLD: 2
#             accuracy =   0.500200       |  0.500200
#             precision =  0.750050  |   recall =    0.500200   |  f1 =    0.333778
# Test image dataset:  10000
#             pt file:  (0.8368_0.5000_0.5000)_fold_3/step/best_test_acc_200_0.500000.pt
#   FOLD: 3
#             accuracy =   0.500000       |  0.500000
#             precision =  0.250000  |   recall =    0.500000   |  f1 =    0.333333
# Test image dataset:  10000
#             pt file:  (0.8034_0.5166_0.5493)_fold_4/step/best_test_acc_7200_0.549300.pt
#   FOLD: 4
#             accuracy =   0.535900       |  0.535900
#             precision =  0.539614  |   recall =    0.535900   |  f1 =    0.524761
#
#
#  ================ monkey CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.6628_0.5568_0.5937)_fold_0/step/best_test_acc_1200_0.593700.pt
#   FOLD: 0
#             accuracy =   0.561500       |  0.561500
#             precision =  0.596493  |   recall =    0.561500   |  f1 =    0.517781
# Test image dataset:  10000
#             pt file:  (0.6596_0.5765_0.5903)_fold_1/step/best_test_acc_1400_0.590300.pt
#   FOLD: 1
#             accuracy =   0.551600       |  0.551600
#             precision =  0.585132  |   recall =    0.551600   |  f1 =    0.502623
# Test image dataset:  10000
#             pt file:  (0.6675_0.5937_0.5937)_fold_2/step/best_test_acc_1200_0.593700.pt
#   FOLD: 2
#             accuracy =   0.567600       |  0.567600
#             precision =  0.594510  |   recall =    0.567600   |  f1 =    0.534462
# Test image dataset:  10000
#             pt file:  (0.6583_0.5945_0.6033)_fold_3/step/best_test_acc_1400_0.603300.pt
#   FOLD: 3
#             accuracy =   0.571800       |  0.571800
#             precision =  0.620570  |   recall =    0.571800   |  f1 =    0.523627
# Test image dataset:  10000
#             pt file:  (0.6572_0.5509_0.5817)_fold_4/step/best_test_acc_1600_0.581700.pt
#   FOLD: 4
#             accuracy =   0.561500       |  0.561500
#             precision =  0.595986  |   recall =    0.561500   |  f1 =    0.518227
#
#
#  ================ reenact CHECKPOINT ================
# Test image dataset:  9566
#             pt file:  (0.0100_0.9989_0.9989)_fold_0/step/best_test_acc_11200_0.998850.pt
#   FOLD: 0
#             accuracy =   0.994250       |  0.994252
#             precision =  0.994058  |   recall =    0.994481   |  f1 =    0.994241
# Test image dataset:  9566
#             pt file:  (0.0188_0.9990_0.9990)_fold_1/step/best_test_acc_16200_0.998955.pt
#   FOLD: 1
#             accuracy =   0.796049       |  0.795957
#             precision =  0.858393  |   recall =    0.786432   |  f1 =    0.782723
# Test image dataset:  9566
#             pt file:  (0.0098_0.9999_0.9999)_fold_2/step/best_test_acc_12800_0.999895.pt
#   FOLD: 2
#             accuracy =   0.983170       |  0.983173
#             precision =  0.984357  |   recall =    0.982389   |  f1 =    0.983105
# Test image dataset:  9566
#             pt file:  (0.0034_0.9994_0.9997)_fold_3/step/best_test_acc_17400_0.999686.pt
#   FOLD: 3
#             accuracy =   0.991323       |  0.991325
#             precision =  0.991756  |   recall =    0.990959   |  f1 =    0.991299
# Test image dataset:  9566
#             pt file:  (0.0040_0.9987_0.9993)_fold_4/step/best_test_acc_12800_0.999268.pt
#   FOLD: 4
#             accuracy =   0.997805       |  0.997805
#             precision =  0.997726  |   recall =    0.997881   |  f1 =    0.997801
#
#
#  ================ stargan CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.5570_0.8461_0.8461)_fold_0/step/best_test_acc_18600_0.846100.pt
#   FOLD: 0
#             accuracy =   0.739700       |  0.739700
#             precision =  0.742393  |   recall =    0.739700   |  f1 =    0.738975
# Test image dataset:  10000
#             pt file:  (0.2329_0.9104_0.9165)_fold_1/step/best_test_acc_16400_0.916500.pt
#   FOLD: 1
#             accuracy =   0.804500       |  0.804500
#             precision =  0.806592  |   recall =    0.804500   |  f1 =    0.804166
# Test image dataset:  10000
#             pt file:  (0.2943_0.9251_0.9251)_fold_2/step/best_test_acc_3400_0.925100.pt
#   FOLD: 2
#             accuracy =   0.799200       |  0.799200
#             precision =  0.826343  |   recall =    0.799200   |  f1 =    0.794936
# Test image dataset:  10000
#             pt file:  (0.5558_0.7556_0.7806)_fold_3/step/best_test_acc_14400_0.780600.pt
#   FOLD: 3
#             accuracy =   0.677300       |  0.677300
#             precision =  0.727296  |   recall =    0.677300   |  f1 =    0.658522
# Test image dataset:  10000
#             pt file:  (0.4826_0.6937_0.7180)_fold_4/step/best_test_acc_7400_0.718000.pt
#   FOLD: 4
#             accuracy =   0.593700       |  0.593700
#             precision =  0.699975  |   recall =    0.593700   |  f1 =    0.531448
#
#
#  ================ x2face CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.2236_0.8271_0.8483)_fold_0/step/best_test_acc_200_0.848300.pt
#   FOLD: 0
#             accuracy =   0.764400       |  0.764400
#             precision =  0.803169  |   recall =    0.764400   |  f1 =    0.756619
# Test image dataset:  10000
#             pt file:  (0.1875_0.8138_0.8635)_fold_1/step/best_test_acc_8600_0.863500.pt
#   FOLD: 1
#             accuracy =   0.806000       |  0.806000
#             precision =  0.820801  |   recall =    0.806000   |  f1 =    0.803736
# Test image dataset:  10000
#             pt file:  (0.1208_0.8860_0.9010)_fold_2/step/best_test_acc_11000_0.901000.pt
#   FOLD: 2
#             accuracy =   0.889100       |  0.889100
#             precision =  0.896676  |   recall =    0.889100   |  f1 =    0.888568
# Test image dataset:  10000
#             pt file:  (0.2645_0.7685_0.8545)_fold_3/step/best_test_acc_600_0.854500.pt
#   FOLD: 3
#             accuracy =   0.722800       |  0.722800
#             precision =  0.788212  |   recall =    0.722800   |  f1 =    0.706126
# Test image dataset:  10000
#             pt file:  (0.2340_0.7916_0.8721)_fold_4/step/best_test_acc_1200_0.872100.pt
#   FOLD: 4
#             accuracy =   0.741700       |  0.741700
#             precision =  0.756551  |   recall =    0.741700   |  f1 =    0.737907
#
# *********************************************************
#              BRIGHTNESS:  1.5
#
#
#  ================ deepfake CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.0888_0.9064_0.9525)_fold_0/step/best_test_acc_18000_0.952500.pt
#   FOLD: 0
#             accuracy =   0.907900       |  0.907900
#             precision =  0.922097  |   recall =    0.907900   |  f1 =    0.907119
# Test image dataset:  10000
#             pt file:  (0.0901_0.9372_0.9434)_fold_1/step/best_test_acc_16200_0.943400.pt
#   FOLD: 1
#             accuracy =   0.944200       |  0.944200
#             precision =  0.947992  |   recall =    0.944200   |  f1 =    0.944082
# Test image dataset:  10000
#             pt file:  (0.0982_0.8780_0.8948)_fold_2/step/best_test_acc_10800_0.894800.pt
#   FOLD: 2
#             accuracy =   0.821900       |  0.821900
#             precision =  0.863252  |   recall =    0.821900   |  f1 =    0.816683
# Test image dataset:  10000
#             pt file:  (0.0983_0.9043_0.9128)_fold_3/step/best_test_acc_17200_0.912800.pt
#   FOLD: 3
#             accuracy =   0.731000       |  0.731000
#             precision =  0.821614  |   recall =    0.731000   |  f1 =    0.710617
# Test image dataset:  10000
#             pt file:  (0.2025_0.8786_0.9478)_fold_4/step/best_test_acc_17000_0.947800.pt
#   FOLD: 4
#             accuracy =   0.897100       |  0.897100
#             precision =  0.914308  |   recall =    0.897100   |  f1 =    0.896020
#
#
#  ================ 3dmm CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.0198_0.9927_0.9927)_fold_0/step/best_test_acc_6200_0.992700.pt
#   FOLD: 0
#             accuracy =   0.986100       |  0.986100
#             precision =  0.986414  |   recall =    0.986100   |  f1 =    0.986098
# Test image dataset:  10000
#             pt file:  (0.0584_0.9768_0.9768)_fold_1/step/best_test_acc_11600_0.976800.pt
#   FOLD: 1
#             accuracy =   0.981700       |  0.981700
#             precision =  0.982304  |   recall =    0.981700   |  f1 =    0.981694
# Test image dataset:  10000
#             pt file:  (0.0175_0.9921_0.9921)_fold_2/step/best_test_acc_20000_0.992100.pt
#   FOLD: 2
#             accuracy =   0.980600       |  0.980600
#             precision =  0.980859  |   recall =    0.980600   |  f1 =    0.980597
# Test image dataset:  10000
#             pt file:  (0.0128_0.9971_0.9971)_fold_3/step/best_test_acc_12000_0.997100.pt
#   FOLD: 3
#             accuracy =   0.995900       |  0.995900
#             precision =  0.995900  |   recall =    0.995900   |  f1 =    0.995900
# Test image dataset:  10000
#             pt file:  (0.0309_0.9910_0.9910)_fold_4/step/best_test_acc_12000_0.991000.pt
#   FOLD: 4
#             accuracy =   0.981800       |  0.981800
#             precision =  0.982282  |   recall =    0.981800   |  f1 =    0.981795
#
#
#  ================ faceswap_2d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.3051_0.5196_0.5760)_fold_0/step/best_test_acc_16000_0.576000.pt
#   FOLD: 0
#             accuracy =   0.592500       |  0.592500
#             precision =  0.598890  |   recall =    0.592500   |  f1 =    0.585809
# Test image dataset:  10000
#             pt file:  (0.9974_0.5000_0.5044)_fold_1/step/best_test_acc_8400_0.504400.pt
#   FOLD: 1
#             accuracy =   0.500000       |  0.500000
#             precision =  0.500000  |   recall =    0.500000   |  f1 =    0.334220
# Test image dataset:  10000
#             pt file:  (0.2139_0.5051_0.5352)_fold_2/step/best_test_acc_5800_0.535200.pt
#   FOLD: 2
#             accuracy =   0.554200       |  0.554200
#             precision =  0.572383  |   recall =    0.554200   |  f1 =    0.524328
# Test image dataset:  10000
#             pt file:  (0.1882_0.5182_0.5268)_fold_3/step/best_test_acc_5000_0.526800.pt
#   FOLD: 3
#             accuracy =   0.506300       |  0.506300
#             precision =  0.667380  |   recall =    0.506300   |  f1 =    0.349890
# Test image dataset:  10000
#             pt file:  (0.7512_0.4999_0.5000)_fold_4/step/best_test_acc_400_0.500000.pt
#   FOLD: 4
#             accuracy =   0.500000       |  0.500000
#             precision =  0.250000  |   recall =    0.500000   |  f1 =    0.333333
#
#
#  ================ faceswap_3d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.7323_0.5000_0.5084)_fold_0/step/best_test_acc_19800_0.508400.pt
#   FOLD: 0
#             accuracy =   0.516000       |  0.516000
#             precision =  0.532870  |   recall =    0.516000   |  f1 =    0.444758
# Test image dataset:  10000
#             pt file:  (0.5359_0.5008_0.5573)_fold_1/step/best_test_acc_1600_0.557300.pt
#   FOLD: 1
#             accuracy =   0.554300       |  0.554300
#             precision =  0.555038  |   recall =    0.554300   |  f1 =    0.552801
# Test image dataset:  10000
#             pt file:  (0.9268_0.5000_0.5002)_fold_2/step/best_test_acc_6000_0.500200.pt
#   FOLD: 2
#             accuracy =   0.501300       |  0.501300
#             precision =  0.620696  |   recall =    0.501300   |  f1 =    0.337445
# Test image dataset:  10000
#             pt file:  (0.8368_0.5000_0.5000)_fold_3/step/best_test_acc_200_0.500000.pt
#   FOLD: 3
#             accuracy =   0.498000       |  0.498000
#             precision =  0.374498  |   recall =    0.498000   |  f1 =    0.334203
# Test image dataset:  10000
#             pt file:  (0.8034_0.5166_0.5493)_fold_4/step/best_test_acc_7200_0.549300.pt
#   FOLD: 4
#             accuracy =   0.531100       |  0.531100
#             precision =  0.551246  |   recall =    0.531100   |  f1 =    0.479992
#
#
#  ================ monkey CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.6628_0.5568_0.5937)_fold_0/step/best_test_acc_1200_0.593700.pt
#   FOLD: 0
#             accuracy =   0.523700       |  0.523700
#             precision =  0.633633  |   recall =    0.523700   |  f1 =    0.400381
# Test image dataset:  10000
#             pt file:  (0.6596_0.5765_0.5903)_fold_1/step/best_test_acc_1400_0.590300.pt
#   FOLD: 1
#             accuracy =   0.551400       |  0.551400
#             precision =  0.609088  |   recall =    0.551400   |  f1 =    0.483058
# Test image dataset:  10000
#             pt file:  (0.6675_0.5937_0.5937)_fold_2/step/best_test_acc_1200_0.593700.pt
#   FOLD: 2
#             accuracy =   0.522900       |  0.522900
#             precision =  0.624546  |   recall =    0.522900   |  f1 =    0.400603
# Test image dataset:  10000
#             pt file:  (0.6583_0.5945_0.6033)_fold_3/step/best_test_acc_1400_0.603300.pt
#   FOLD: 3
#             accuracy =   0.531700       |  0.531700
#             precision =  0.626602  |   recall =    0.531700   |  f1 =    0.423700
# Test image dataset:  10000
#             pt file:  (0.6572_0.5509_0.5817)_fold_4/step/best_test_acc_1600_0.581700.pt
#   FOLD: 4
#             accuracy =   0.563500       |  0.563500
#             precision =  0.599630  |   recall =    0.563500   |  f1 =    0.519981
#
#
#  ================ reenact CHECKPOINT ================
# Test image dataset:  9566
#             pt file:  (0.0100_0.9989_0.9989)_fold_0/step/best_test_acc_11200_0.998850.pt
#   FOLD: 0
#             accuracy =   0.995819       |  0.995819
#             precision =  0.995970  |   recall =    0.995667   |  f1 =    0.995809
# Test image dataset:  9566
#             pt file:  (0.0188_0.9990_0.9990)_fold_1/step/best_test_acc_16200_0.998955.pt
#   FOLD: 1
#             accuracy =   0.992578       |  0.992579
#             precision =  0.992969  |   recall =    0.992244   |  f1 =    0.992557
# Test image dataset:  9566
#             pt file:  (0.0098_0.9999_0.9999)_fold_2/step/best_test_acc_12800_0.999895.pt
#   FOLD: 2
#             accuracy =   0.976061       |  0.976051
#             precision =  0.978075  |   recall =    0.974933   |  f1 =    0.975946
# Test image dataset:  9566
#             pt file:  (0.0034_0.9994_0.9997)_fold_3/step/best_test_acc_17400_0.999686.pt
#   FOLD: 3
#             accuracy =   0.613109       |  0.613055
#             precision =  0.786755  |   recall =    0.594731   |  f1 =    0.524313
# Test image dataset:  9566
#             pt file:  (0.0040_0.9987_0.9993)_fold_4/step/best_test_acc_12800_0.999268.pt
#   FOLD: 4
#             accuracy =   0.745244       |  0.745222
#             precision =  0.835946  |   recall =    0.733146   |  f1 =    0.720063
#
#
#  ================ stargan CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.5570_0.8461_0.8461)_fold_0/step/best_test_acc_18600_0.846100.pt
#   FOLD: 0
#             accuracy =   0.795800       |  0.795800
#             precision =  0.825399  |   recall =    0.795800   |  f1 =    0.791048
# Test image dataset:  10000
#             pt file:  (0.2329_0.9104_0.9165)_fold_1/step/best_test_acc_16400_0.916500.pt
#   FOLD: 1
#             accuracy =   0.759400       |  0.759400
#             precision =  0.823380  |   recall =    0.759400   |  f1 =    0.746880
# Test image dataset:  10000
#             pt file:  (0.2943_0.9251_0.9251)_fold_2/step/best_test_acc_3400_0.925100.pt
#   FOLD: 2
#             accuracy =   0.819600       |  0.819600
#             precision =  0.853676  |   recall =    0.819600   |  f1 =    0.815147
# Test image dataset:  10000
#             pt file:  (0.5558_0.7556_0.7806)_fold_3/step/best_test_acc_14400_0.780600.pt
#   FOLD: 3
#             accuracy =   0.691300       |  0.691300
#             precision =  0.781377  |   recall =    0.691300   |  f1 =    0.664445
# Test image dataset:  10000
#             pt file:  (0.4826_0.6937_0.7180)_fold_4/step/best_test_acc_7400_0.718000.pt
#   FOLD: 4
#             accuracy =   0.690800       |  0.690800
#             precision =  0.799475  |   recall =    0.690800   |  f1 =    0.659950
#
#
#  ================ x2face CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.2236_0.8271_0.8483)_fold_0/step/best_test_acc_200_0.848300.pt
#   FOLD: 0
#             accuracy =   0.626400       |  0.626400
#             precision =  0.780132  |   recall =    0.626400   |  f1 =    0.566993
# Test image dataset:  10000
#             pt file:  (0.1875_0.8138_0.8635)_fold_1/step/best_test_acc_8600_0.863500.pt
#   FOLD: 1
#             accuracy =   0.869300       |  0.869300
#             precision =  0.880748  |   recall =    0.869300   |  f1 =    0.868310
# Test image dataset:  10000
#             pt file:  (0.1208_0.8860_0.9010)_fold_2/step/best_test_acc_11000_0.901000.pt
#   FOLD: 2
#             accuracy =   0.807600       |  0.807600
#             precision =  0.856880  |   recall =    0.807600   |  f1 =    0.800721
# Test image dataset:  10000
#             pt file:  (0.2645_0.7685_0.8545)_fold_3/step/best_test_acc_600_0.854500.pt
#   FOLD: 3
#             accuracy =   0.740400       |  0.740400
#             precision =  0.818840  |   recall =    0.740400   |  f1 =    0.723387
# Test image dataset:  10000
#             pt file:  (0.2340_0.7916_0.8721)_fold_4/step/best_test_acc_1200_0.872100.pt
#   FOLD: 4
#             accuracy =   0.831400       |  0.831400
#             precision =  0.864658  |   recall =    0.831400   |  f1 =    0.827466
#
# *********************************************************
#              BRIGHTNESS:  2.0
#
#
#  ================ deepfake CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.0888_0.9064_0.9525)_fold_0/step/best_test_acc_18000_0.952500.pt
#   FOLD: 0
#             accuracy =   0.685000       |  0.685000
#             precision =  0.806492  |   recall =    0.685000   |  f1 =    0.650350
# Test image dataset:  10000
#             pt file:  (0.0901_0.9372_0.9434)_fold_1/step/best_test_acc_16200_0.943400.pt
#   FOLD: 1
#             accuracy =   0.752500       |  0.752500
#             precision =  0.832710  |   recall =    0.752500   |  f1 =    0.736626
# Test image dataset:  10000
#             pt file:  (0.0982_0.8780_0.8948)_fold_2/step/best_test_acc_10800_0.894800.pt
#   FOLD: 2
#             accuracy =   0.613100       |  0.613100
#             precision =  0.778451  |   recall =    0.613100   |  f1 =    0.545649
# Test image dataset:  10000
#             pt file:  (0.0983_0.9043_0.9128)_fold_3/step/best_test_acc_17200_0.912800.pt
#   FOLD: 3
#             accuracy =   0.576100       |  0.576100
#             precision =  0.768009  |   recall =    0.576100   |  f1 =    0.483670
# Test image dataset:  10000
#             pt file:  (0.2025_0.8786_0.9478)_fold_4/step/best_test_acc_17000_0.947800.pt
#   FOLD: 4
#             accuracy =   0.646700       |  0.646700
#             precision =  0.791992  |   recall =    0.646700   |  f1 =    0.596507
#
#
#  ================ 3dmm CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.0198_0.9927_0.9927)_fold_0/step/best_test_acc_6200_0.992700.pt
#   FOLD: 0
#             accuracy =   0.958900       |  0.958900
#             precision =  0.961609  |   recall =    0.958900   |  f1 =    0.958840
# Test image dataset:  10000
#             pt file:  (0.0584_0.9768_0.9768)_fold_1/step/best_test_acc_11600_0.976800.pt
#   FOLD: 1
#             accuracy =   0.955300       |  0.955300
#             precision =  0.958582  |   recall =    0.955300   |  f1 =    0.955220
# Test image dataset:  10000
#             pt file:  (0.0175_0.9921_0.9921)_fold_2/step/best_test_acc_20000_0.992100.pt
#   FOLD: 2
#             accuracy =   0.948100       |  0.948100
#             precision =  0.951119  |   recall =    0.948100   |  f1 =    0.948013
# Test image dataset:  10000
#             pt file:  (0.0128_0.9971_0.9971)_fold_3/step/best_test_acc_12000_0.997100.pt
#   FOLD: 3
#             accuracy =   0.988600       |  0.988600
#             precision =  0.988604  |   recall =    0.988600   |  f1 =    0.988600
# Test image dataset:  10000
#             pt file:  (0.0309_0.9910_0.9910)_fold_4/step/best_test_acc_12000_0.991000.pt
#   FOLD: 4
#             accuracy =   0.952500       |  0.952500
#             precision =  0.956015  |   recall =    0.952500   |  f1 =    0.952408
#
#
#  ================ faceswap_2d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.3051_0.5196_0.5760)_fold_0/step/best_test_acc_16000_0.576000.pt
#   FOLD: 0
#             accuracy =   0.605400       |  0.605400
#             precision =  0.606691  |   recall =    0.605400   |  f1 =    0.604203
# Test image dataset:  10000
#             pt file:  (0.9974_0.5000_0.5044)_fold_1/step/best_test_acc_8400_0.504400.pt
#   FOLD: 1
#             accuracy =   0.499900       |  0.499900
#             precision =  0.416642  |   recall =    0.499900   |  f1 =    0.333467
# Test image dataset:  10000
#             pt file:  (0.2139_0.5051_0.5352)_fold_2/step/best_test_acc_5800_0.535200.pt
#   FOLD: 2
#             accuracy =   0.572300       |  0.572300
#             precision =  0.592599  |   recall =    0.572300   |  f1 =    0.547502
# Test image dataset:  10000
#             pt file:  (0.1882_0.5182_0.5268)_fold_3/step/best_test_acc_5000_0.526800.pt
#   FOLD: 3
#             accuracy =   0.503600       |  0.503600
#             precision =  0.633259  |   recall =    0.503600   |  f1 =    0.344040
# Test image dataset:  10000
#             pt file:  (0.7512_0.4999_0.5000)_fold_4/step/best_test_acc_400_0.500000.pt
#   FOLD: 4
#             accuracy =   0.499800       |  0.499800
#             precision =  0.249950  |   recall =    0.499800   |  f1 =    0.333244
#
#
#  ================ faceswap_3d CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.7323_0.5000_0.5084)_fold_0/step/best_test_acc_19800_0.508400.pt
#   FOLD: 0
#             accuracy =   0.524600       |  0.524600
#             precision =  0.535677  |   recall =    0.524600   |  f1 =    0.484595
# Test image dataset:  10000
#             pt file:  (0.5359_0.5008_0.5573)_fold_1/step/best_test_acc_1600_0.557300.pt
#   FOLD: 1
#             accuracy =   0.535600       |  0.535600
#             precision =  0.535989  |   recall =    0.535600   |  f1 =    0.534341
# Test image dataset:  10000
#             pt file:  (0.9268_0.5000_0.5002)_fold_2/step/best_test_acc_6000_0.500200.pt
#   FOLD: 2
#             accuracy =   0.501700       |  0.501700
#             precision =  0.530573  |   recall =    0.501700   |  f1 =    0.347691
# Test image dataset:  10000
#             pt file:  (0.8368_0.5000_0.5000)_fold_3/step/best_test_acc_200_0.500000.pt
#   FOLD: 3
#             accuracy =   0.503500       |  0.503500
#             precision =  0.540849  |   recall =    0.503500   |  f1 =    0.356382
# Test image dataset:  10000
#             pt file:  (0.8034_0.5166_0.5493)_fold_4/step/best_test_acc_7200_0.549300.pt
#   FOLD: 4
#             accuracy =   0.517800       |  0.517800
#             precision =  0.544884  |   recall =    0.517800   |  f1 =    0.432135
#
#
#  ================ monkey CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.6628_0.5568_0.5937)_fold_0/step/best_test_acc_1200_0.593700.pt
#   FOLD: 0
#             accuracy =   0.503200       |  0.503200
#             precision =  0.625805  |   recall =    0.503200   |  f1 =    0.343169
# Test image dataset:  10000
#             pt file:  (0.6596_0.5765_0.5903)_fold_1/step/best_test_acc_1400_0.590300.pt
#   FOLD: 1
#             accuracy =   0.519700       |  0.519700
#             precision =  0.622125  |   recall =    0.519700   |  f1 =    0.392277
# Test image dataset:  10000
#             pt file:  (0.6675_0.5937_0.5937)_fold_2/step/best_test_acc_1200_0.593700.pt
#   FOLD: 2
#             accuracy =   0.503600       |  0.503600
#             precision =  0.598734  |   recall =    0.503600   |  f1 =    0.346081
# Test image dataset:  10000
#             pt file:  (0.6583_0.5945_0.6033)_fold_3/step/best_test_acc_1400_0.603300.pt
#   FOLD: 3
#             accuracy =   0.509800       |  0.509800
#             precision =  0.601303  |   recall =    0.509800   |  f1 =    0.366818
# Test image dataset:  10000
#             pt file:  (0.6572_0.5509_0.5817)_fold_4/step/best_test_acc_1600_0.581700.pt
#   FOLD: 4
#             accuracy =   0.531000       |  0.531000
#             precision =  0.606763  |   recall =    0.531000   |  f1 =    0.429850
#
#
#  ================ reenact CHECKPOINT ================
# Test image dataset:  9566
#             pt file:  (0.0100_0.9989_0.9989)_fold_0/step/best_test_acc_11200_0.998850.pt
#   FOLD: 0
#             accuracy =   0.826260       |  0.826236
#             precision =  0.873798  |   recall =    0.818107   |  f1 =    0.817690
# Test image dataset:  9566
#             pt file:  (0.0188_0.9990_0.9990)_fold_1/step/best_test_acc_16200_0.998955.pt
#   FOLD: 1
#             accuracy =   0.798766       |  0.798749
#             precision =  0.860697  |   recall =    0.789222   |  f1 =    0.785783
# Test image dataset:  9566
#             pt file:  (0.0098_0.9999_0.9999)_fold_2/step/best_test_acc_12800_0.999895.pt
#   FOLD: 2
#             accuracy =   0.600669       |  0.600618
#             precision =  0.783447  |   recall =    0.581691   |  f1 =    0.502231
# Test image dataset:  9566
#             pt file:  (0.0034_0.9994_0.9997)_fold_3/step/best_test_acc_17400_0.999686.pt
#   FOLD: 3
#             accuracy =   0.554986       |  0.554900
#             precision =  0.768463  |   recall =    0.533847   |  f1 =    0.414248
# Test image dataset:  9566
#             pt file:  (0.0040_0.9987_0.9993)_fold_4/step/best_test_acc_12800_0.999268.pt
#   FOLD: 4
#             accuracy =   0.531466       |  0.531355
#             precision =  0.763657  |   recall =    0.509198   |  f1 =    0.363321
#
#
#  ================ stargan CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.5570_0.8461_0.8461)_fold_0/step/best_test_acc_18600_0.846100.pt
#   FOLD: 0
#             accuracy =   0.654400       |  0.654400
#             precision =  0.737362  |   recall =    0.654400   |  f1 =    0.621310
# Test image dataset:  10000
#             pt file:  (0.2329_0.9104_0.9165)_fold_1/step/best_test_acc_16400_0.916500.pt
#   FOLD: 1
#             accuracy =   0.576200       |  0.576200
#             precision =  0.744937  |   recall =    0.576200   |  f1 =    0.488025
# Test image dataset:  10000
#             pt file:  (0.2943_0.9251_0.9251)_fold_2/step/best_test_acc_3400_0.925100.pt
#   FOLD: 2
#             accuracy =   0.612000       |  0.612000
#             precision =  0.760297  |   recall =    0.612000   |  f1 =    0.547558
# Test image dataset:  10000
#             pt file:  (0.5558_0.7556_0.7806)_fold_3/step/best_test_acc_14400_0.780600.pt
#   FOLD: 3
#             accuracy =   0.645300       |  0.645300
#             precision =  0.734429  |   recall =    0.645300   |  f1 =    0.608045
# Test image dataset:  10000
#             pt file:  (0.4826_0.6937_0.7180)_fold_4/step/best_test_acc_7400_0.718000.pt
#   FOLD: 4
#             accuracy =   0.613600       |  0.613600
#             precision =  0.762179  |   recall =    0.613600   |  f1 =    0.549820
#
#
#  ================ x2face CHECKPOINT ================
# Test image dataset:  10000
#             pt file:  (0.2236_0.8271_0.8483)_fold_0/step/best_test_acc_200_0.848300.pt
#   FOLD: 0
#             accuracy =   0.520600       |  0.520600
#             precision =  0.755258  |   recall =    0.520600   |  f1 =    0.377545
# Test image dataset:  10000
#             pt file:  (0.1875_0.8138_0.8635)_fold_1/step/best_test_acc_8600_0.863500.pt
#   FOLD: 1
#             accuracy =   0.776500       |  0.776500
#             precision =  0.830880  |   recall =    0.776500   |  f1 =    0.766924
# Test image dataset:  10000
#             pt file:  (0.1208_0.8860_0.9010)_fold_2/step/best_test_acc_11000_0.901000.pt
#   FOLD: 2
#             accuracy =   0.679000       |  0.679000
#             precision =  0.800843  |   recall =    0.679000   |  f1 =    0.642837
# Test image dataset:  10000
#             pt file:  (0.2645_0.7685_0.8545)_fold_3/step/best_test_acc_600_0.854500.pt
#   FOLD: 3
#             accuracy =   0.573500       |  0.573500
#             precision =  0.765190  |   recall =    0.573500   |  f1 =    0.479427
# Test image dataset:  10000
#             pt file:  (0.2340_0.7916_0.8721)_fold_4/step/best_test_acc_1200_0.872100.pt
#   FOLD: 4
#             accuracy =   0.661100       |  0.661100
#             precision =  0.792467  |   recall =    0.661100   |  f1 =    0.618230
